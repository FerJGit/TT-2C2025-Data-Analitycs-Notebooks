# %% [markdown]
# # Actividades

# %%
import math

num = input("Ingrese un número")

if num.isnumeric():
  if(int(num)%2==0):
    print("Es par")
  else:
    print("Es impar")
else:
  print("debe ser un número")
# Out:
# Ingrese un númeroA
# debe ser un número

# %% [markdown]
# # **TT252813 - Data Analytics con Python**
# Esta es una prueba de texto para la ***Actividad 1*** en *Colab* 💪💪💪
#
# ### Presione este [**link**](https://tt-252813-data-analytics.vercel.app/#/semana1) para ver la página del curso
#
# Imagen
#
# <img src="https://drive.google.com/uc?id=1c4l8h2Apnp-07ehgmJrO2v-znI7tuVNs" width=300px height=200px>

# %% [markdown]
# ## Actividad 1

# %% [markdown]
#   Creá tu propio bloque de texto. Utiliza:
#   - formatos de texto
#   - links
#   - al menos una imagen de tu carpeta Drive

# %% [markdown]
# ## Actividad 2

# %% [markdown]
# Creá un bloque de código con un programa que pida un número por teclado, y responda si es par o impar. Ejecutalo.

# %% [markdown]
# <a href="https://colab.research.google.com/github/FerJGit/TT-2C2025-Data-Analitycs-Notebooks/blob/main/Clase_3/Clase_03_NB2_Import_datasets_con_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Métodos para importar datasets con Pandas

# %% [markdown]
# Links que vamos a usar:

# %% [markdown]
# * [Blog Kaggle - International Hotel Booking Analytics](https://www.kaggle.com/code/sonawanelalitsunil/international-hotel-booking-analytics-ml-34-75/notebook)
# * [Datasets Kaggle - International Hotel Booking Analytics](https://www.kaggle.com/datasets/alperenmyung/international-hotel-booking-analytics)
# * [Dataset Github - LifeExpectancy ](https://raw.githubusercontent.com/resbaz/r-novice-gapminder-files/master/data/gapminder-FiveYearData.csv)
# * [Dataset Kaggle - Netflix](https://www.kaggle.com/datasets/shivamb/netflix-shows/code)

# %% [markdown]
# # 1. Descargar los datasets (archivos .csv) antes de comenzar

# %% [markdown]
# * Opción 1:
# Decargarlos desde el Repositorio Oficial del Curso [Click Aquí](https://drive.google.com/drive/folders/1LI3HcSqcrSJ52YZAoQG0NNmdOnHVSJHG)
# * Opción 2:
# Decargarlos desde Kaggle [Click Aquí](https://www.kaggle.com/datasets/alperenmyung/international-hotel-booking-analytics) - Haciendo click en el botón Download/Descargar (Debe descomprimir el archivo "archive.zip")

# %% [markdown]
# # 2. Preparar los archivos en Google Drive

# %% [markdown]
# 1. Crear en su unidad de Google Drive la carpeta "datasets"
# 2. Subir a esa carpeta los archivos:
# * hotels.csv
# * reviews.csv
# * users.csv

# %% [markdown]
# # 3 Montar y liberar la unidad

# %% [markdown]
# Este código permite montar la unidad de su Drive en este ambiente virtual de Colab

# %%
# Montar la unidad
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Al finalizar la actividad o en caso que lo requiera, puede desmontar la unidad con este código

# %%
# Liberar la unidad
drive.flush_and_unmount()

# %% [markdown]
# # 4. Importar datasets

# %% [markdown]
# A continuación veremos varias opciones para importar datasets a Google Colab usando Pandas, el método dependerá de la necesidad y de sus conocimientos, por ello se plantean varios escenarios para cada nivel.

# %% [markdown]
# ## 4.1 Importar datasets desde Google Sheets  (Nivel Inicial)

# %%
# Importar la librería Pandas
import pandas as pd

# %%
# Acceso a Gsheets - Metodo con URL de conversion a CSV (lectura)
# El archivo debe tener permisos de lectura para TODOS
ID_planilla = '1LeWVQ0Pd9XlQ70oTWggueRGLBXISMTGDiLG7wZ6otSI'
URL = f'https://docs.google.com/spreadsheets/d/{ID_planilla}/gviz/tq?tqx=out:csv&sheet='
df_gs = pd.read_csv(URL + 'ventas')
df_gs.head()
# Out:
#    user_id user_gender         country age_group traveller_type   join_date  \
# 0        1      Female  United Kingdom     35-44           Solo  2024-09-29
# 1        2        Male  United Kingdom     25-34           Solo  2023-11-29
# 2        3      Female          Mexico     25-34         Family  2022-04-03
# 3        4        Male           India     35-44         Family  2023-12-02
# 4        5       Other           Japan     25-34           Solo  2021-12-18
#
#   edad_agregada
# 0         10.50
# 1         10.25
# 2          25,5
# 3           NaN
# 4           NaN

# %% [markdown]
# ## 4.2 Importar datasets desde Google Drive  (Nivel Inicial)

# %% [markdown]
# En esta instancia, ya deberías tener creada la carpeta `datasets` en el raíz de tu Unidad de Google Drive, y ahi haber subido los archivos csv que vamos a usar

# %%
# Verificar que los archivos csv se encuentren en la carpeta datasets
import os
os.listdir("/content/drive/MyDrive/datasets")
# Out:
# ['netflix-shows.zip',
#  'booking_db.sqlite',
#  'hotels.csv',
#  'users.csv',
#  'reviews.csv',
#  'netflix_titles.csv',
#  'ventas.csv',
#  'Prueba.xlsx',
#  'satis_clientes.csv']

# %%
# Importar la librería Pandas
import pandas as pd

# %%
# Usar el método read_csv de Pandas (pd) que recibe como argumento el archivo csv y retorna un dataframe
df_users = pd.read_csv('/content/drive/MyDrive/datasets/users.csv')
df_users.head()
# Out:
#    user_id user_gender         country age_group traveller_type   join_date
# 0        1      Female  United Kingdom     35-44           Solo  2024-09-29
# 1        2        Male  United Kingdom     25-34           Solo  2023-11-29
# 2        3      Female          Mexico     25-34         Family  2022-04-03
# 3        4        Male           India     35-44         Family  2023-12-02
# 4        5       Other           Japan     25-34           Solo  2021-12-18

# %% [markdown]
# ## 4.3 Importar datasets desde Google Drive (Nivel Intermedio)

# %% [markdown]
# Si van a trabajar con datasets que se encuentran en diferentes carpetas, puden cambiar la ruta por defecto

# %% [markdown]
# 1. Se sugiere usar el panel de navegación laterar para explorar las carpetas y sus archivos.
# 2. Cambiar la ruta original al directorio donde se encuentran los archivos .csv que se quieren importar

# %%
# Validar la ruta y la existencia del archivo csv a importar
import os
os.chdir("/content/drive/MyDrive/datasets")
os.listdir(".")
# Out:
# ['netflix-shows.zip',
#  'booking_db.sqlite',
#  'hotels.csv',
#  'users.csv',
#  'reviews.csv',
#  'netflix_titles.csv',
#  'ventas.csv',
#  'Prueba.xlsx',
#  'satis_clientes.csv']

# %%
# Importar la librería Pandas
import pandas as pd

# %%
# Usar el método read_csv de Pandas (pd) que recibe como argumento el archivo csv y retorna un dataframe
df = pd.read_csv('users.csv')
df.head()
# Out:
#    user_id user_gender         country age_group traveller_type   join_date
# 0        1      Female  United Kingdom     35-44           Solo  2024-09-29
# 1        2        Male  United Kingdom     25-34           Solo  2023-11-29
# 2        3      Female          Mexico     25-34         Family  2022-04-03
# 3        4        Male           India     35-44         Family  2023-12-02
# 4        5       Other           Japan     25-34           Solo  2021-12-18

# %% [markdown]
# ## 4.4 Importar datasets desde Github

# %%
# Cargar en una variable la URL del archivo csv de Github
url = "https://raw.githubusercontent.com/resbaz/r-novice-gapminder-files/master/data/gapminder-FiveYearData.csv"

# %%
# Importar la librería Pandas
import pandas as pd

# %%
# Usar el método read_csv de Pandas (pd) que recibe como argumento el archivo csv y retorna un dataframe
df_github = pd.read_csv(url)
df_github.head()
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 0  Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3  Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4  Afghanistan  1972  13079460.0      Asia   36.088  739.981106

# %% [markdown]
# ## 4.5 Importar Datasets públicos desde Kaggle (Nivel Avanzado)
#
#
# > Para datasets públicos que no requieren autenticación

# %% [markdown]
# Cuando quieran descargar un dataset público desde Kaggle, hacer click en download y pegrn el código "Download Via kagglehub"
# <BR>
# En este caso vamos a descargar el dataset [Netflix Movies](https://www.kaggle.com/datasets/shivamb/netflix-shows/code)

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("shivamb/netflix-shows")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'netflix-shows' dataset.
# Path to dataset files: /kaggle/input/netflix-shows

# %% [markdown]
# Kagglehub descarga sus archivos en un cache, path informa la ruta.
# <BR>
# Lo que hacemos es copiarlo a la carpeta "datasets" de nuestro drive

# %%
# Montar la unidad
from google.colab import drive
drive.mount('/content/drive')

# %%
import os, shutil
# Carpeta destino
dest_dir = "/content/drive/MyDrive/datasets/"

# Copiar todos los archivos del dataset al destino
for file in os.listdir(path):
    shutil.copy(os.path.join(path, file), dest_dir)

print("Archivos copiados a:", dest_dir)
print("Contenido:", os.listdir(dest_dir))
# Out:
# Archivos copiados a: /content/drive/MyDrive/datasets/
# Contenido: ['netflix-shows.zip', 'booking_db.sqlite', 'hotels.csv', 'users.csv', 'reviews.csv', 'netflix_titles.csv', 'ventas.csv', 'Prueba.xlsx', 'satis_clientes.csv']

# %%
# Usar el método read_csv de Pandas (pd) que recibe como argumento el archivo csv y retorna un dataframe
df = pd.read_csv(f"{path}/netflix_titles.csv")
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %% [markdown]
# ## 4.6 Importar Datasets privados desde Kaggle (Nivel Avanzado)
#
#
# > Para datasets privados que si requieren autenticación

# %% [markdown]
# Crear una carpeta en el raíz del Drive llamada `kaggle` y pegar el archivo `kaggle.json` (API Token) que generan desde su perfil de Kaggle

# %%
# Montar la unidad
from google.colab import drive
drive.mount('/content/drive')

# %%
# Validar la existencia del JSON
import os
os.listdir("/content/drive/MyDrive/kaggle")
# Out:
# ['kaggle.json']

# %% [markdown]
# Este código crear una carpeta kaggle en el raíz y la segunda linea un copy/paste de `kaggle.json`

# %%
# !mkdir -p ~/.kaggle
# !cp /content/drive/MyDrive/kaggle/kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# En este caso vamos a descargar el mismo dataset [Netflix Movies](https://www.kaggle.com/datasets/shivamb/netflix-shows/code)
# <BR>
# Aunque al ser público esto no es necesario

# %%
# Este código descarga el dataset con las credenciales
# !kaggle datasets download -d shivamb/netflix-shows -p /content/drive/MyDrive/datasets
# !unzip /content/drive/MyDrive/datasets/netflix-shows.zip -d /content/drive/MyDrive/datasets
# Out:
# Dataset URL: https://www.kaggle.com/datasets/shivamb/netflix-shows
# License(s): CC0-1.0
# netflix-shows.zip: Skipping, found more recently modified local copy (use --force to force download)
# Archive:  /content/drive/MyDrive/datasets/netflix-shows.zip
# replace /content/drive/MyDrive/datasets/netflix_titles.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: /content/drive/MyDrive/datasets/netflix_titles.csv

# %%
# Validar la existencia del archivo descargado
import os
os.listdir("/content/drive/MyDrive/datasets")
# Out:
# ['netflix-shows.zip',
#  'booking_db.sqlite',
#  'hotels.csv',
#  'users.csv',
#  'reviews.csv',
#  'netflix_titles.csv',
#  'ventas.csv',
#  'Prueba.xlsx',
#  'satis_clientes.csv']

# %%
# Importar la librería Pandas
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/datasets/netflix_titles.csv")
print(df.shape)   # cantidad de filas y columnas
df.head()         # primeras 5 filas
# Out:
# (8807, 12)
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %% [markdown]
# ## 4.7 Importar Datos desde una base de datos relacional ya subida a la carpeta datasets del raíz

# %% [markdown]
# En esta modalidad, deben descargar la carpeta zip desde desde este link
# <BR>
# [Descargar](https://www.kaggle.com/datasets/alperenmyung/international-hotel-booking-analytics)
# <BR>
# Descomprimir la carpeta y subir el archivo `booking_db.sqlite` a la carpeta `/datasets` de su Drive

# %%
# Montar la unidad
from google.colab import drive
drive.mount('/content/drive')

# %%
# Validar la existencia de la DB
import os
os.listdir("/content/drive/MyDrive/datasets")
# Out:
# ['netflix-shows.zip',
#  'booking_db.sqlite',
#  'hotels.csv',
#  'users.csv',
#  'reviews.csv',
#  'netflix_titles.csv',
#  'ventas.csv',
#  'Prueba.xlsx',
#  'satis_clientes.csv']

# %%
# Importamos las librerías
import sqlite3
import pandas as pd

# %%
# Establecemos la conexión a la db
conexion = sqlite3.connect('/content/drive/MyDrive/datasets/booking_db.sqlite')

# %%
df = pd.read_sql('''
    SELECT
        *
    FROM reviews
    ;
''', conexion, index_col='review_id', parse_dates=['review_date'])
print(df)
# Out:
#            user_id  hotel_id review_date  score_overall  score_cleanliness  \
# review_id
# 1             1600         1  2022-10-07            8.7                8.6
# 2              432         4  2020-03-24            9.1               10.0
# 3              186        18  2023-12-18            8.8                9.7
# 4             1403        19  2022-06-22            8.9                9.0
# 5             1723        17  2022-07-02            9.1                8.9
# ...            ...       ...         ...            ...                ...
# 49996         1786        24  2022-08-07            8.4                8.2
# 49997         1739         8  2025-03-05            8.8                8.8
# 49998         1566         6  2025-05-03            9.1                9.8
# 49999           10        21  2024-09-27            9.0                8.7
# 50000         1626        19  2022-02-09            9.2                9.7
#
#            score_comfort  score_facilities  score_location  score_staff  \
# review_id
# 1                    8.7               8.5             9.0          8.8
# 2                    9.1               9.0             8.6          9.4
# 3                    8.8               8.3             8.7          8.1
# 4                    8.8               8.5             9.6          9.1
# 5                    9.5               9.3             8.3          9.4
# ...                  ...               ...             ...          ...
# 49996                8.2               8.5             9.1          8.3
# 49997                9.0               8.0             9.5          8.8
# 49998                9.1               8.5             9.6          9.3
# 49999                9.1               8.7             9.7          9.0
# 50000                9.4               9.0             9.5          8.9
#
#            score_value_for_money  \
# review_id
# 1                            8.7
# 2                            8.6
# 3                            8.6
# 4                            8.3
# 5                            8.9
# ...                          ...
# 49996                        7.5
# 49997                        8.7
# 49998                        8.0
# 49999                        8.7
# 50000                        8.8
#
#                                                  review_text
# review_id
# 1          Practice reduce young our because machine. Rec...
# 2          Test cover traditional black. Process tell Mr ...
# 3          Friend million student social study yeah. Grow...
# 4          Huge girl already remain truth behind card. Ap...
# 5          Cover feeling call community serve television ...
# ...                                                      ...
# 49996      Thing her against garden method magazine. Inte...
# 49997      But benefit away major. Story kid often offici...
# 49998      But certainly part special moment certain buil...
# 49999      Ask suffer space return. Hospital material the...
# 50000      Story student tax various. Child whole only ch...
#
# [50000 rows x 11 columns]

# %%
df = pd.read_sql('''
    SELECT
    review_id, hotel_name, city, star_rating, score_overall, u.country
    FROM hotels h
    join reviews r on h.hotel_id = r.hotel_id
    join users u on r.user_id = u.user_id
    order by score_overall asc
    ;
''', conexion, index_col='review_id')
print (df)
# Out:
#                    hotel_name         city  star_rating  score_overall  \
# review_id
# 24325      The Savannah House        Lagos            5            8.2
# 47012      The Savannah House        Lagos            5            8.2
# 20651           Aztec Heights  Mexico City            5            8.3
# 35092           Aztec Heights  Mexico City            5            8.3
# 37190           Aztec Heights  Mexico City            5            8.3
# ...                       ...          ...          ...            ...
# 3806        Canal House Grand    Amsterdam            5            9.5
# 9116        Canal House Grand    Amsterdam            5            9.5
# 16294       Canal House Grand    Amsterdam            5            9.5
# 34163       Canal House Grand    Amsterdam            5            9.5
# 36255        The Golden Oasis        Dubai            5            9.6
#
#                  country
# review_id
# 24325            Nigeria
# 47012              Spain
# 20651             France
# 35092             Turkey
# 37190      United States
# ...                  ...
# 3806             Nigeria
# 9116         New Zealand
# 16294        South Korea
# 34163      United States
# 36255        South Korea
#
# [50000 rows x 5 columns]

# %%
df = pd.read_sql('''
    SELECT
    review_id, hotel_name, city, avg(score_overall)
    FROM hotels h
    join reviews r on h.hotel_id = r.hotel_id
    group by hotel_name, city
    order by avg(score_overall) desc
    ;
''', conexion, index_col='review_id')
print(df)
print (df["hotel_name"])
# Out:
#                      hotel_name            city  avg(score_overall)
# review_id
# 39             The Golden Oasis           Dubai            9.092432
# 50            Canal House Grand       Amsterdam            9.090713
# 8             Marina Bay Zenith       Singapore            9.053598
# 20              The Bund Palace        Shanghai            9.050441
# 77            Colosseum Gardens            Rome            9.044140
# 4               Gaudi's Retreat       Barcelona            9.036734
# 38              The Maple Grove         Toronto            9.035692
# 43              Han River Oasis           Seoul            9.016997
# 15               The Kiwi Grand      Wellington            9.016311
# 24            The Orchid Palace         Bangkok            9.006521
# 14           Berlin Mitte Elite          Berlin            9.002324
# 10          Table Mountain View       Cape Town            8.979434
# 2                  Kyo-to Grand           Tokyo            8.969457
# 5                Kremlin Suites          Moscow            8.966954
# 19              L'Étoile Palace           Paris            8.947065
# 31            The Bosphorus Inn        Istanbul            8.913655
# 6          Sydney Harbour Grand          Sydney            8.901228
# 22            The Royal Compass          London            8.881020
# 126              Copacabana Lux  Rio de Janeiro            8.869113
# 9            The Gateway Royale          Mumbai            8.841227
# 1               The Azure Tower        New York            8.835135
# 7                Tango Boutique    Buenos Aires            8.822495
# 3                 Nile Grandeur           Cairo            8.759696
# 34                Aztec Heights     Mexico City            8.759381
# 21           The Savannah House           Lagos            8.694632
# review_id
# 39         The Golden Oasis
# 50        Canal House Grand
# 8         Marina Bay Zenith
# 20          The Bund Palace
# 77        Colosseum Gardens
# 4           Gaudi's Retreat
# 38          The Maple Grove
# 43          Han River Oasis
# 15           The Kiwi Grand
# 24        The Orchid Palace
# 14       Berlin Mitte Elite
# 10      Table Mountain View
# 2              Kyo-to Grand
# 5            Kremlin Suites
# 19          L'Étoile Palace
# 31        The Bosphorus Inn
# 6      Sydney Harbour Grand
# 22        The Royal Compass
# 126          Copacabana Lux
# 9        The Gateway Royale
# 1           The Azure Tower
# 7            Tango Boutique
# 3             Nile Grandeur
# 34            Aztec Heights
# 21       The Savannah House
# Name: hotel_name, dtype: object

# %% [markdown]
# ## 4.8 Importar Datos desde una base de datos relacional (usando credenciales de Kaggle - descarga directa)

# %%
# Montar la unidad
from google.colab import drive
drive.mount('/content/drive')

# %%
# Validar la existencia del JSON
import os
os.listdir("/content/drive/MyDrive/kaggle")
# Out:
# ['kaggle.json']

# %%
# Creamos una carpeta temporal en el ambiente virtual
# !mkdir -p ~/.kaggle
# ahí pegamos las credenciales
# !cp /content/drive/MyDrive/kaggle/kaggle.json ~/.kaggle/
# cambiamos los permisos
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# Este código descarga el dataset con las credenciales a la carpeta datasets
# !kaggle datasets download -d alperenmyung/international-hotel-booking-analytics -p /content/drive/MyDrive/datasets
# y con esta línea hacemos el unzip
# !unzip /content/drive/MyDrive/datasets/international-hotel-booking-analytics.zip -d /content/drive/MyDrive/datasets
# Out:
# Dataset URL: https://www.kaggle.com/datasets/alperenmyung/international-hotel-booking-analytics
# License(s): CC0-1.0
# Downloading international-hotel-booking-analytics.zip to /content/drive/MyDrive/datasets
#   0% 0.00/6.30M [00:00<?, ?B/s]
# 100% 6.30M/6.30M [00:00<00:00, 179MB/s]
# Archive:  /content/drive/MyDrive/datasets/international-hotel-booking-analytics.zip
# replace /content/drive/MyDrive/datasets/booking_db.sqlite? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: /content/drive/MyDrive/datasets/booking_db.sqlite
# replace /content/drive/MyDrive/datasets/hotels.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: /content/drive/MyDrive/datasets/hotels.csv
# replace /content/drive/MyDrive/datasets/reviews.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: /content/drive/MyDrive/datasets/reviews.csv
# replace /content/drive/MyDrive/datasets/users.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: /content/drive/MyDrive/datasets/users.csv

# %%
# Importamos las librerías
import sqlite3
import pandas as pd

# %%
# Establecemos la conexión a la db
conexion = sqlite3.connect('/content/drive/MyDrive/datasets/booking_db.sqlite')

# %%
df = pd.read_sql('''
    SELECT
        *
    FROM reviews
    ;
''', conexion, index_col='review_id', parse_dates=['review_date'])
print (df)
# Out:
#            user_id  hotel_id review_date  score_overall  score_cleanliness  \
# review_id
# 1             1600         1  2022-10-07            8.7                8.6
# 2              432         4  2020-03-24            9.1               10.0
# 3              186        18  2023-12-18            8.8                9.7
# 4             1403        19  2022-06-22            8.9                9.0
# 5             1723        17  2022-07-02            9.1                8.9
# ...            ...       ...         ...            ...                ...
# 49996         1786        24  2022-08-07            8.4                8.2
# 49997         1739         8  2025-03-05            8.8                8.8
# 49998         1566         6  2025-05-03            9.1                9.8
# 49999           10        21  2024-09-27            9.0                8.7
# 50000         1626        19  2022-02-09            9.2                9.7
#
#            score_comfort  score_facilities  score_location  score_staff  \
# review_id
# 1                    8.7               8.5             9.0          8.8
# 2                    9.1               9.0             8.6          9.4
# 3                    8.8               8.3             8.7          8.1
# 4                    8.8               8.5             9.6          9.1
# 5                    9.5               9.3             8.3          9.4
# ...                  ...               ...             ...          ...
# 49996                8.2               8.5             9.1          8.3
# 49997                9.0               8.0             9.5          8.8
# 49998                9.1               8.5             9.6          9.3
# 49999                9.1               8.7             9.7          9.0
# 50000                9.4               9.0             9.5          8.9
#
#            score_value_for_money  \
# review_id
# 1                            8.7
# 2                            8.6
# 3                            8.6
# 4                            8.3
# 5                            8.9
# ...                          ...
# 49996                        7.5
# 49997                        8.7
# 49998                        8.0
# 49999                        8.7
# 50000                        8.8
#
#                                                  review_text
# review_id
# 1          Practice reduce young our because machine. Rec...
# 2          Test cover traditional black. Process tell Mr ...
# 3          Friend million student social study yeah. Grow...
# 4          Huge girl already remain truth behind card. Ap...
# 5          Cover feeling call community serve television ...
# ...                                                      ...
# 49996      Thing her against garden method magazine. Inte...
# 49997      But benefit away major. Story kid often offici...
# 49998      But certainly part special moment certain buil...
# 49999      Ask suffer space return. Hospital material the...
# 50000      Story student tax various. Child whole only ch...
#
# [50000 rows x 11 columns]

# %%
df = pd.read_sql('''
    SELECT
    review_id, hotel_name, city, star_rating, score_overall, u.country
    FROM hotels h
    join reviews r on h.hotel_id = r.hotel_id
    join users u on r.user_id = u.user_id
    order by score_overall asc
    ;
''', conexion, index_col='review_id')
print (df)
# Out:
#                    hotel_name         city  star_rating  score_overall  \
# review_id
# 24325      The Savannah House        Lagos            5            8.2
# 47012      The Savannah House        Lagos            5            8.2
# 20651           Aztec Heights  Mexico City            5            8.3
# 35092           Aztec Heights  Mexico City            5            8.3
# 37190           Aztec Heights  Mexico City            5            8.3
# ...                       ...          ...          ...            ...
# 3806        Canal House Grand    Amsterdam            5            9.5
# 9116        Canal House Grand    Amsterdam            5            9.5
# 16294       Canal House Grand    Amsterdam            5            9.5
# 34163       Canal House Grand    Amsterdam            5            9.5
# 36255        The Golden Oasis        Dubai            5            9.6
#
#                  country
# review_id
# 24325            Nigeria
# 47012              Spain
# 20651             France
# 35092             Turkey
# 37190      United States
# ...                  ...
# 3806             Nigeria
# 9116         New Zealand
# 16294        South Korea
# 34163      United States
# 36255        South Korea
#
# [50000 rows x 5 columns]

# %%
df = pd.read_sql('''
    SELECT
    review_id, hotel_name, city, avg(score_overall)
    FROM hotels h
    join reviews r on h.hotel_id = r.hotel_id
    group by hotel_name, city
    order by avg(score_overall) desc
    ;
''', conexion, index_col='review_id')
print (df)
# Out:
#                      hotel_name            city  avg(score_overall)
# review_id
# 39             The Golden Oasis           Dubai            9.092432
# 50            Canal House Grand       Amsterdam            9.090713
# 8             Marina Bay Zenith       Singapore            9.053598
# 20              The Bund Palace        Shanghai            9.050441
# 77            Colosseum Gardens            Rome            9.044140
# 4               Gaudi's Retreat       Barcelona            9.036734
# 38              The Maple Grove         Toronto            9.035692
# 43              Han River Oasis           Seoul            9.016997
# 15               The Kiwi Grand      Wellington            9.016311
# 24            The Orchid Palace         Bangkok            9.006521
# 14           Berlin Mitte Elite          Berlin            9.002324
# 10          Table Mountain View       Cape Town            8.979434
# 2                  Kyo-to Grand           Tokyo            8.969457
# 5                Kremlin Suites          Moscow            8.966954
# 19              L'Étoile Palace           Paris            8.947065
# 31            The Bosphorus Inn        Istanbul            8.913655
# 6          Sydney Harbour Grand          Sydney            8.901228
# 22            The Royal Compass          London            8.881020
# 126              Copacabana Lux  Rio de Janeiro            8.869113
# 9            The Gateway Royale          Mumbai            8.841227
# 1               The Azure Tower        New York            8.835135
# 7                Tango Boutique    Buenos Aires            8.822495
# 3                 Nile Grandeur           Cairo            8.759696
# 34                Aztec Heights     Mexico City            8.759381
# 21           The Savannah House           Lagos            8.694632

# %%
df.head()
# Out:
#                   hotel_name       city  avg(score_overall)
# review_id
# 39          The Golden Oasis      Dubai            9.092432
# 50         Canal House Grand  Amsterdam            9.090713
# 8          Marina Bay Zenith  Singapore            9.053598
# 20           The Bund Palace   Shanghai            9.050441
# 77         Colosseum Gardens       Rome            9.044140

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25 entries, 39 to 21
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   hotel_name          25 non-null     object
#  1   city                25 non-null     object
#  2   avg(score_overall)  25 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 800.0+ bytes

# %%
df.dtypes
# Out:
# hotel_name             object
# city                   object
# avg(score_overall)    float64
# dtype: object

# %%
df.describe()
# Out:
#        avg(score_overall)
# count           25.000000
# mean             8.943456
# std              0.110675
# min              8.694632
# 25%              8.869113
# 50%              8.969457
# 75%              9.035692
# max              9.092432

# %% [markdown]
# <a href="https://colab.research.google.com/github/FerJGit/TT-2C2025-Data-Analitycs-Notebooks/blob/main/EntregaFinal/Mis_Archivos/EntregaFinal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Análisis de datos con Python - Entrega Final
# Nombre y Apellido: **Fernando Gabriel Jaleh**
#
# Comisión: **252613**
#
# **TPI Data Analytics**

# %% [markdown]
# # **Etapa 1**

# %% [markdown]
# ## Script básico para carga de ventas y cálculo de total acumulado
# Actividades 2 y 3

# %%
# Clase para imprimir en color y negrita
class color:
   DARKCYAN = '\033[36m'
   BOLD = '\033[1m'
   END = '\033[0m'

# %%
# Genero una lista de diccionarios (producto, precio, cantidad) con algunos datos de ejemplo
ventas = [
  {'producto': 'remera', 'precio': 9500, 'cantidad': 3},
  {'producto': 'pantalón', 'precio': 50000, 'cantidad': 1},
  {'producto': 'buzo', 'precio': 30000, 'cantidad': 2}
]

# %%
# Calculo total de ventas con map y función lambda
total_ventas = sum(map(lambda venta: venta['precio'] * venta['cantidad'], ventas))

# Imprimo el total en negrita, color darkcyan, con el $ adelante, el punto como separador de miles en lugar de coma, y sin decimales (porque los precios tampoco tienen decimales)
print("El total de ventas es: " + color.BOLD + color.DARKCYAN + f"${'{:,.0f}'.format(total_ventas).replace(',', '.')}" + color.END)
# Out:
# El total de ventas es: $138.500

# %%
# Calculo total de ventas acumuladas con listas por comprensión
total_ventas = sum([venta["precio"] * venta["cantidad"] for venta in ventas])

# Imprimo el total en negrita, color darkcyan, con el $ adelante, el punto como separador de miles en lugar de coma, y sin decimales (porque los precios tampoco tienen decimales)
print("El total de ventas es: " + color.BOLD + color.DARKCYAN + f"${'{:,.0f}'.format(total_ventas).replace(',', '.')}" + color.END)
# Out:
# El total de ventas es: $138.500

# %% [markdown]
# ## Carga de Datasets
# Actividad 1

# %%
import pandas as pd

# %%
# Importo el dataset ventas desde mi github
df_ventas = pd.read_csv("https://raw.githubusercontent.com/FerJGit/TT-2C2025-Data-Analitycs-Notebooks/refs/heads/main/PreEntrega/Datasets/ventas.csv")

# %%
# Importo el dataset marketing desde mi github
df_marketing = pd.read_csv("https://raw.githubusercontent.com/FerJGit/TT-2C2025-Data-Analitycs-Notebooks/refs/heads/main/PreEntrega/Datasets/marketing.csv")

# %%
# Importo el dataset clientes desde mi github
df_clientes = pd.read_csv("https://raw.githubusercontent.com/FerJGit/TT-2C2025-Data-Analitycs-Notebooks/refs/heads/main/PreEntrega/Datasets/clientes.csv")

# %%
# Veo lo que trae el dataset de ventas
df_ventas
# Out:
#       id_venta                producto   precio  cantidad fecha_venta  \
# 0          792       Cuadro decorativo   $69.94       5.0  02/01/2024
# 1          811         Lámpara de mesa  $105.10       5.0  02/01/2024
# 2         1156                Secadora   $97.96       3.0  02/01/2024
# 3         1372                Heladera  $114.35       8.0  02/01/2024
# 4         1546                Secadora  $106.21       4.0  02/01/2024
# ...        ...                     ...      ...       ...         ...
# 3030      1837         Horno eléctrico  $104.12       9.0  30/12/2024
# 3031      2276                  Laptop   $85.27       9.0  30/12/2024
# 3032      2696                  Laptop  $107.81       4.0  30/12/2024
# 3033      2913              Smartphone   $99.85       7.0  30/12/2024
# 3034      2930  Consola de videojuegos   $55.47       6.0  30/12/2024
#
#               categoria
# 0            Decoración
# 1            Decoración
# 2     Electrodomésticos
# 3     Electrodomésticos
# ...

# %%
# Veo lo que trae el dataset de marketing
df_marketing
# Out:
#     id_campanha            producto  canal  costo fecha_inicio   fecha_fin
# 0            74     Adorno de pared     TV   4.81   20/03/2024  03/05/2024
# 1            12              Tablet   RRSS   3.40   26/03/2024  13/05/2024
# 2            32     Lámpara de mesa  Email   5.54   28/03/2024  20/04/2024
# 3            21          Smartphone   RRSS   6.37   29/03/2024  16/05/2024
# 4            58            Alfombra  Email   4.25   31/03/2024  05/05/2024
# ..          ...                 ...    ...    ...          ...         ...
# 85           70          Aspiradora     TV   3.06   13/12/2024  29/12/2024
# 86           89           Televisor     TV   4.98   13/12/2024    8/2/2025
# 87           68   Rincón de plantas     TV   5.81   17/12/2024   14/2/2025
# 88           33            Secadora  Email   3.80   20/12/2024    7/1/2025
# 89           11  Freidora eléctrica   RRSS   5.27   29/12/2024   21/1/2025
#
# [90 rows x 6 columns]

# %%
# Veo lo que trae el dataset de clientes
df_clientes
# Out:
#      id_cliente               nombre  edad         ciudad  ingresos
# 0             1      Aloysia Screase    44  Mar del Plata  42294.68
# 1             2  Kristina Scaplehorn    25        Posadas  24735.04
# 2             3       Filip Castagne    50    Resistencia  35744.85
# 3             4          Liuka Luard    39   Bahía Blanca  27647.96
# 4             5        Dore Cockshtt    28        Rosario  28245.65
# ..          ...                  ...   ...            ...       ...
# 562         563        Dione Forsyde    29        Posadas  26757.73
# 563         564          Fleming Gow    39       Santa Fe  43674.96
# 564         565      Jewelle Mabbett    33        Córdoba  30522.64
# 565         566          Lauri Munns    23    Resistencia  31259.14
# 566         567          Micah Matis    31     Corrientes  42927.86
#
# [567 rows x 5 columns]

# %% [markdown]
# ## Dataframe <font color="red">**ventas**</font>

# %% [markdown]
# ### Análisis exploratorio de datos
# Actividad 4

# %% [markdown]
# Aplicamos los métodos de EDA vistos en clase, `info`, `columns`, `dtypes`, `head`, `tail`, `sample`, `unique`, `value_counts`, `describe`, `duplicated`, `isnull`, etc. y documentamos las observaciones:

# %%
# Aplico info() para obtener información del dataframe
df_ventas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3035 entries, 0 to 3034
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id_venta     3035 non-null   int64
#  1   producto     3035 non-null   object
#  2   precio       3033 non-null   object
#  3   cantidad     3033 non-null   float64
#  4   fecha_venta  3035 non-null   object
#  5   categoria    3035 non-null   object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 142.4+ KB

# %%
# Visualizo los primeros registros con head(). En este caso le digo que quiero ver los 7 primeros.
# (también se puede usar tail() para visualizar los últimos)
df_ventas.head(7)
# Out:
#    id_venta           producto   precio  cantidad fecha_venta  \
# 0       792  Cuadro decorativo   $69.94       5.0  02/01/2024
# 1       811    Lámpara de mesa  $105.10       5.0  02/01/2024
# 2      1156           Secadora   $97.96       3.0  02/01/2024
# 3      1372           Heladera  $114.35       8.0  02/01/2024
# 4      1546           Secadora  $106.21       4.0  02/01/2024
# 5      1697    Horno eléctrico   $35.35       9.0  02/01/2024
# 6      1710   Plancha de vapor   $65.43       2.0  02/01/2024
#
#            categoria
# 0         Decoración
# 1         Decoración
# 2  Electrodomésticos
# 3  Electrodomésticos
# 4  Electrodomésticos
# 5  Electrodomésticos
# 6  Electrodomésticos

# %%
# Uso sample() para tomar registros al azar, en este caso 5
df_ventas.sample(5)
# Out:
#       id_venta            producto   precio  cantidad fecha_venta  \
# 2985      2513          Smartphone  $119.12       8.0  24/12/2024
# 2896      1465            Lavadora   $61.87       8.0  14/12/2024
# 2902       529     Lámpara de mesa   $64.12       6.0  15/12/2024
# 1134       353   Espejo decorativo   $43.92      11.0  05/05/2024
# 336       1501  Freidora eléctrica   $58.69       4.0  08/02/2024
#
#               categoria
# 2985        Electrónica
# 2896  Electrodomésticos
# 2902         Decoración
# 1134         Decoración
# 336   Electrodomésticos

# %%
# Analizo el campo precio tomando 5 registros al azar
# Como no es de tipo numérico, no puedo aplicar describe()
df_ventas["precio"].sample(5)
# Out:
# 2466    $91.79
# 1850    $75.91
# 2218    $83.38
# 83      $79.98
# 2581    $85.31
# Name: precio, dtype: object

# %%
# Analizo el campo cantidad tomando 5 registros al azar
df_ventas["cantidad"].sample(5)
# Out:
# 481      1.0
# 1255    10.0
# 1046     9.0
# 212     10.0
# 218      1.0
# Name: cantidad, dtype: float64

# %%
# Como es numérico puedo aplicar describe() para ver algunos datos estadisticos
df_ventas["cantidad"].describe()
# Out:
# count    3033.000000
# mean        6.496538
# std         3.457250
# min         1.000000
# 25%         3.000000
# 50%         7.000000
# 75%         9.000000
# max        12.000000
# Name: cantidad, dtype: float64

# %%
# Analizo el campo fecha_venta
df_ventas["fecha_venta"].sample(5)
# Out:
# 233     28/01/2024
# 11      03/01/2024
# 457     23/02/2024
# 516     29/02/2024
# 1401    04/06/2024
# Name: fecha_venta, dtype: object

# %%
# Analizo el campo categoria. Veo cuántos valores hay y qué cantidad de cada uno.
df_ventas["categoria"].value_counts()
# Out:
# categoria
# Decoración           1015
# Electrónica          1012
# Electrodomésticos    1008
# Name: count, dtype: int64

# %%
# Veo los valores únicos
df_ventas["categoria"].unique()
# Out:
# array(['Decoración', 'Electrodomésticos', 'Electrónica'], dtype=object)

# %% [markdown]
# ### Calidad de los datos
# Actividad 5

# %%
# Busco los registros duplicados
df_ventas.duplicated().sum()
# Out:
# np.int64(35)

# %%
# Visualizo los duplicados con keep=False para que tome todas las repeticiones de cada uno, y los ordeno por producto.
# keep: 'first', 'last', False
df_ventas[df_ventas.duplicated(keep=False)].sort_values(by="producto")
# Out:
#      id_venta         producto   precio  cantidad fecha_venta    categoria
# 845       300  Adorno de pared   $67.75       9.0  06/04/2024   Decoración
# 833       300  Adorno de pared   $67.75       9.0  06/04/2024   Decoración
# 857       345         Alfombra   $56.78       9.0  07/04/2024   Decoración
# 832       145         Alfombra   $41.72       8.0  06/04/2024   Decoración
# 868       345         Alfombra   $56.78       9.0  07/04/2024   Decoración
# ..        ...              ...      ...       ...         ...          ...
# 854      2108       SmartWatch   $79.37      10.0  06/04/2024  Electrónica
# 831      2778       SmartWatch   $70.66       7.0  05/04/2024  Electrónica
# 825      2778       SmartWatch   $70.66       7.0  05/04/2024  Electrónica
# 877      2373       Smartphone  $123.60      12.0  07/04/2024  Electrónica
# 866      2373       Smartphone  $123.60      12.0  07/04/2024  Electrónica
#
# [70 rows x 6 columns]

# %%
# Busco datos nulos
df_ventas.isnull().sum()
# Out:
# id_venta       0
# producto       0
# precio         2
# cantidad       2
# fecha_venta    0
# categoria      0
# dtype: int64

# %%
# Visualizo los nulos a nivel filas (con axis=1)
df_ventas[df_ventas.isnull().any(axis=1)]
# Out:
#      id_venta               producto precio  cantidad fecha_venta    categoria
# 136       627  Elementos de cerámica    NaN       NaN  17/01/2024   Decoración
# 139      2171    Parlantes Bluetooth    NaN       NaN  17/01/2024  Electrónica

# %%
# Analizo los precios de los NaN para ver qué opciones tengo
# df_ventas[df_ventas["producto"]=="Elementos de cerámica"]
# df_ventas[df_ventas["producto"]=="Parlantes Bluetooth"]
# df_ventas["producto"].unique()
df_ventas["producto"].value_counts()
# Out:
# producto
# Lámpara de mesa           181
# Auriculares               147
# Microondas                135
# Cafetera                  118
# Laptop                    104
# Secadora                  103
# Jarrón decorativo         102
# Smartphone                102
# Alfombra                  102
# SmartWatch                102
# Aspiradora                102
# Cortinas                  102
# Rincón de plantas         102
# Freidora eléctrica        101
# Espejo decorativo         101
# Adorno de pared           101
# Lavadora                  100
# Consola de videojuegos    100
# Cuadro decorativo         100
# Horno eléctrico           100
# Plancha de vapor          100
# Proyector                 100
# Elementos de cerámica     100
# Batidora                  100
# Televisor                 100
# Cámara digital            100
# Parlantes Bluetooth        99
# Tablet                     58
# Heladera                   49
# Candelabro                 24
# Name: count, dtype: int64

# %% [markdown]
# ### Observaciones

# %% [markdown]
# * Cantidad de registros: 3035
# * Columnas : 6
# * Duplicados: 35, eliminarlos
# * Nulos : 2, el 1% del faltante, dropna
# * Campo precio: encontre `$`, removerlo y luego cambiar el dtype a float64
# * Campo fecha: ajustar el dtype a datetime
# * Campos producto y categoria: cambiar el dtype a string

# %% [markdown]
# ## Dataframe <font color="red">**marketing**</font>

# %% [markdown]
# ### Analisis exploratorio de datos

# %% [markdown]
# Aplicamos los métodos de EDA vistos en clase, `info`, `columns`, `dtypes`, `head`, `tail`, `sample`, `unique`, `value_counts`, `describe`, `duplicated`, `isnull`, etc. y documentamos las observaciones:

# %%
# Aplico info() para obtener información del dataframe
df_marketing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id_campanha   90 non-null     int64
#  1   producto      90 non-null     object
#  2   canal         90 non-null     object
#  3   costo         90 non-null     float64
#  4   fecha_inicio  90 non-null     object
#  5   fecha_fin     90 non-null     object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 4.3+ KB

# %%
# Visualizo los primeros registros con head()
# (también se puede usar tail() para visualizar los últimos)
df_marketing.head()
# Out:
#    id_campanha         producto  canal  costo fecha_inicio   fecha_fin
# 0           74  Adorno de pared     TV   4.81   20/03/2024  03/05/2024
# 1           12           Tablet   RRSS   3.40   26/03/2024  13/05/2024
# 2           32  Lámpara de mesa  Email   5.54   28/03/2024  20/04/2024
# 3           21       Smartphone   RRSS   6.37   29/03/2024  16/05/2024
# 4           58         Alfombra  Email   4.25   31/03/2024  05/05/2024

# %%
# Analizo el campo producto
df_marketing["producto"].value_counts()
# Out:
# producto
# Adorno de pared           3
# Tablet                    3
# Lámpara de mesa           3
# Smartphone                3
# Alfombra                  3
# SmartWatch                3
# Plancha de vapor          3
# Batidora                  3
# Parlantes Bluetooth       3
# Cuadro decorativo         3
# Cortinas                  3
# Consola de videojuegos    3
# Heladera                  3
# Jarrón decorativo         3
# Lavadora                  3
# Televisor                 3
# Proyector                 3
# Candelabro                3
# Espejo decorativo         3
# Auriculares               3
# Freidora eléctrica        3
# Rincón de plantas         3
# Cafetera                  3
# Aspiradora                3
# Elementos de cerámica     3
# Cámara digital            3
# Secadora                  3
# Horno eléctrico           3
# Microondas                3
# Laptop                    3
# Name: count, dtype: int64

# %%
# Analizo el campo canal
df_marketing["canal"].value_counts()
# Out:
# canal
# TV       30
# RRSS     30
# Email    30
# Name: count, dtype: int64

# %%
# Analizo el campo costo
df_marketing["costo"].sample(5)
# Out:
# 1     3.40
# 26    4.37
# 62    4.02
# 19    4.65
# 56    6.28
# Name: costo, dtype: float64

# %%
# Como es de tipo numérico, puedo aplicar describe() para ver algunos datos estadisticos
df_marketing["costo"].describe()
# Out:
# count    90.000000
# mean      4.928667
# std       0.947750
# min       2.950000
# 25%       4.372500
# 50%       4.900000
# 75%       5.562500
# max       7.390000
# Name: costo, dtype: float64

# %%
# Analizo el campo fecha_inicio
df_marketing["fecha_inicio"].sample(5)
# Out:
# 47    09/08/2024
# 72    23/10/2024
# 6     02/04/2024
# 85    13/12/2024
# 57    28/08/2024
# Name: fecha_inicio, dtype: object

# %%
# Analizo el campo fecha_fin
df_marketing["fecha_fin"].sample(5)
# Out:
# 77    25/12/2024
# 20    30/06/2024
# 9     05/05/2024
# 72    11/12/2024
# 36    03/08/2024
# Name: fecha_fin, dtype: object

# %% [markdown]
# ### Calidad de los datos

# %%
# Busco registros duplicados
df_marketing.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Busco nulos
df_marketing.isnull().sum()
# Out:
# id_campanha     0
# producto        0
# canal           0
# costo           0
# fecha_inicio    0
# fecha_fin       0
# dtype: int64

# %% [markdown]
# ### Observaciones
# * Cantidad de registros: 90
# * Columnas: 6
# * Duplicados: 0, no hay
# * Nulos: 0, no hay
# * Campos producto y canal: cambiar el dtype a string
# * Campo fecha_inicio y fecha_fin: cambiar el dtype a datetime

# %% [markdown]
# ## Dataframe <font color="red">**clientes**</font>

# %% [markdown]
# ### Analisis exploratorio de datos

# %% [markdown]
# Aplicamos los métodos de EDA vistos en clase, `info`, `columns`, `dtypes`, `head`, `tail`, `sample`, `unique`, `value_counts`, `describe`, `duplicated`, `isnull`, etc. y documentamos las observaciones:

# %%
# Aplico info() para obtener información del dataframe
df_clientes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 567 entries, 0 to 566
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id_cliente  567 non-null    int64
#  1   nombre      567 non-null    object
#  2   edad        567 non-null    int64
#  3   ciudad      567 non-null    object
#  4   ingresos    567 non-null    float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 22.3+ KB

# %%
# Visualizo los primeros registros con head()
# (también se puede usar tail() para visualizar los últimos)
df_clientes.head()
# Out:
#    id_cliente               nombre  edad         ciudad  ingresos
# 0           1      Aloysia Screase    44  Mar del Plata  42294.68
# 1           2  Kristina Scaplehorn    25        Posadas  24735.04
# 2           3       Filip Castagne    50    Resistencia  35744.85
# 3           4          Liuka Luard    39   Bahía Blanca  27647.96
# 4           5        Dore Cockshtt    28        Rosario  28245.65

# %%
# Analizo el campo edad. Como es numérico puedo usar describe() para ver algunos datos estadisticos
df_clientes["edad"].describe()
# Out:
# count    567.000000
# mean      37.940035
# std       10.202885
# min       20.000000
# 25%       30.000000
# 50%       37.000000
# 75%       43.000000
# max       81.000000
# Name: edad, dtype: float64

# %%
# Analizo el campo ciudad
df_clientes["ciudad"].unique()
# Out:
# array(['Mar del Plata', 'Posadas', 'Resistencia', 'Bahía Blanca',
#        'Rosario', 'San Miguel de Tucumán', 'Córdoba', 'Corrientes',
#        'Santa Fe', 'Merlo', 'Salta', 'Buenos Aires'], dtype=object)

# %%
# Analizo el campo ingresos. Como es numérico puedo usar describe() para ver algunos datos estadisticos
df_clientes["ingresos"].describe()
# Out:
# count      567.000000
# mean     34668.739012
# std      12974.531446
# min        170.290000
# 25%      26015.240000
# 50%      35066.830000
# 75%      42457.100000
# max      88053.010000
# Name: ingresos, dtype: float64

# %% [markdown]
# ### Calidad de los datos

# %%
# Busco registros duplicados
df_clientes.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Busco nulos
df_clientes.isnull().sum()
# Out:
# id_cliente    0
# nombre        0
# edad          0
# ciudad        0
# ingresos      0
# dtype: int64

# %% [markdown]
# ### Observaciones
# * Cantidad de registros: 567
# * Columnas: 5
# * Duplicados: 0, no hay
# * Nulos: 0, no hay
# * Campos nombre y ciudad: cambiar a dtype string

# %% [markdown]
# # Etapa 2

# %% [markdown]
# ## Limpieza de datos
# Actividad 1 - Limpiar el conjunto de datos eliminando duplicados y caracteres no deseados. Documentar el proceso y los resultados.

# %% [markdown]
# ### Dataframe <font color="red">**ventas**</font>

# %% [markdown]
# * 35 duplicados, eliminarlos - se eliminaron 35 duplicados ✅
# * Algunos nulos (2), 1% del faltante, dropna - se eliminaron 2 registros con 2 NaN ✅
# * Campo precio: encontre `$`, removerlo y luego cambiar el dtype a float64 - Ok ✅
# * Campo fecha: ajustar el dtype a datetime - Ok ✅
# * Campos producto y categoria: cambiar el dtype a string - Ok ✅

# %%
# Elimino registros duplicados sobre el mismo dataframe y generando un nuevo índice
# atributos a evaluar, keep, ignore_index, inplace
df_ventas.drop_duplicates(inplace=True, ignore_index=True)

# %%
# Valido que no hayan quedado duplicados
df_ventas.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Elimino registros con datos nulos
df_ventas.dropna(inplace=True)

# %%
# Valido que no hayan quedado nulos
print("Veo isnull:")
print(df_ventas.isnull().sum())

print("\nVeo info para verificar que además se hayan eliminado (total 3035 - duplicados 35 - nulos 2 = 2998):")
df_ventas.info()
# Out:
# Veo isnull:
# id_venta       0
# producto       0
# precio         0
# cantidad       0
# fecha_venta    0
# categoria      0
# dtype: int64
#
# Veo info para verificar que además se hayan eliminado (total 3035 - duplicados 35 - nulos 2 = 2998):
# <class 'pandas.core.frame.DataFrame'>
# Index: 2998 entries, 0 to 2999
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id_venta     2998 non-null   int64
#  1   producto     2998 non-null   object
#  2   precio       2998 non-null   object
#  3   cantidad     2998 non-null   float64
#  4   fecha_venta  2998 non-null   object
#  5   categoria    2998 non-null   object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 164.0+ KB

# %%
# Elimino el caracter especial $ del campo precio
# Normalización: usar replace()
# De ser necesario, podemos usar el atributo regex=True
# uso también strip() para remover espacios del principio y final
df_ventas["precio"] = df_ventas["precio"].str.strip().str.replace("$", "")

# %%
# Valido que precio no contenga $
df_ventas["precio"].sample(3)
# Out:
# 2962     63.48
# 135      87.40
# 1092    119.32
# Name: precio, dtype: object

# %%
# Convierto precio de object a float
# Se puede usar pd.to_numeric o astype o incluso combinarlos
df_ventas["precio"] = df_ventas["precio"].astype(float)

# %%
# Valido la conversion a float
df_ventas["precio"].dtypes
# Out:
# dtype('float64')

# %%
# Convertir el dtype de cantidad, de float64 a int64
df_ventas["cantidad"]= df_ventas["cantidad"].astype(int)

# %%
# Valido la conversion a int64
df_ventas["cantidad"].dtypes
# Out:
# dtype('int64')

# %%
# Convierto el campo fecha_venta a dtype datetime
# pd.to_datetime(df_ventas["fecha_venta"], format="%d/%m/%Y")
# pd.to_datetime(df_ventas["fecha_venta"], dayfirst=True)
df_ventas['fecha_venta'] = pd.to_datetime(df_ventas['fecha_venta'], format="%d/%m/%Y")

# %%
# Valido la conversión de fecha
df_ventas['fecha_venta'].dtype
# Out:
# dtype('<M8[ns]')

# %%
# Convertir el dtype de producto y categoria de object a string
# df_ventas["producto"]= df_ventas["producto"].astype("string")
# df_ventas["categoria"]= df_ventas["categoria"].astype("string")
df_ventas = df_ventas.astype({'producto': 'string', 'categoria': 'string'})

# %%
# Valido la conversión
# df_ventas['producto'].dtype
# df_ventas['categoria'].dtype
df_ventas[['producto', 'categoria']].dtypes
# Out:
# producto     string[python]
# categoria    string[python]
# dtype: object

# %%
# Veo todas las conversiones juntas
df_ventas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2998 entries, 0 to 2999
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id_venta     2998 non-null   int64
#  1   producto     2998 non-null   string
#  2   precio       2998 non-null   float64
#  3   cantidad     2998 non-null   int64
#  4   fecha_venta  2998 non-null   datetime64[ns]
#  5   categoria    2998 non-null   string
# dtypes: datetime64[ns](1), float64(1), int64(2), string(2)
# memory usage: 164.0 KB

# %% [markdown]
# ### Dataframe <font color="red">**marketing**</font>

# %% [markdown]
# * Campos producto y canal: cambiar el dtype a string ✅
# * Campo fecha_inicio y fecha_fin: cambiar el dtype a datetime ✅

# %%
# Convierto los campos producto y canal a string
df_marketing = df_marketing.astype({'producto': 'string', 'canal': 'string'})

# %%
# Convierto el campo fecha_inicio a dtype datetime
df_marketing['fecha_inicio'] = pd.to_datetime(df_marketing['fecha_inicio'], format="%d/%m/%Y")

# %%
# Convierto el campo fecha_fin a dtype datetime
df_marketing['fecha_fin'] = pd.to_datetime(df_marketing['fecha_fin'], format="%d/%m/%Y")

# %%
# Valido todos los cambios juntos
df_marketing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id_campanha   90 non-null     int64
#  1   producto      90 non-null     string
#  2   canal         90 non-null     string
#  3   costo         90 non-null     float64
#  4   fecha_inicio  90 non-null     datetime64[ns]
#  5   fecha_fin     90 non-null     datetime64[ns]
# dtypes: datetime64[ns](2), float64(1), int64(1), string(2)
# memory usage: 4.3 KB

# %% [markdown]
# ### Dataframe <font color="red">**clientes**</font>

# %% [markdown]
# * Campos nombre y ciudad: cambiar a dtype string ✅

# %%
# Convierto los campos nombre y ciudad a string
df_clientes = df_clientes.astype({'nombre': 'string', 'ciudad': 'string'})

# %%
# Valido los cambios
df_clientes[['nombre', 'ciudad']].dtypes
# Out:
# nombre    string[python]
# ciudad    string[python]
# dtype: object

# %% [markdown]
# ## Transformación de datos
# Actividad 2 - Aplicar filtros y transformaciones para crear una tabla de ventas que muestre solo los productos con alto rendimiento.

# %%
# Examino los primeros 2 registros
df_ventas.head(2)
# Out:
#    id_venta           producto  precio  cantidad fecha_venta   categoria
# 0       792  Cuadro decorativo   69.94         5  2024-01-02  Decoración
# 1       811    Lámpara de mesa  105.10         5  2024-01-02  Decoración

# %%
# Transformación:
# Calculo el valor de cada venta = precio * cantidad
# Agrego una nueva columna valor_venta
df_ventas["valor_venta"] = df_ventas["precio"] * df_ventas["cantidad"]

# %%
# Visualizo que se haya generado correctamente
df_ventas.head(2)
# Out:
#    id_venta           producto  precio  cantidad fecha_venta   categoria  \
# 0       792  Cuadro decorativo   69.94         5  2024-01-02  Decoración
# 1       811    Lámpara de mesa  105.10         5  2024-01-02  Decoración
#
#    valor_venta
# 0        349.7
# 1        525.5

# %%
# Agregación:
# Agrupo valor_venta por producto
# Sumo las ventas dentro de cada grupo, generando un nuevo dataframe tabla_ventas y usando producto como índice
# tabla_ventas = (df_ventas.groupby("producto")["valor_venta"].sum())
# Si quiero que producto sea un campo normal y agregar un índice integer, puedo por pasarle el parámetro as_index=False
tabla_ventas = (df_ventas.groupby("producto", as_index=False)["valor_venta"].sum())

tabla_ventas.head()
# Out:
#           producto  valor_venta
# 0  Adorno de pared     48093.49
# 1         Alfombra     44773.06
# 2       Aspiradora     50085.86
# 3      Auriculares     74175.58
# 4         Batidora     50979.20

# %%
# Uso describe para analizar valores estadísticos del campo valor_venta en el dataframe tabla_ventas
tabla_ventas.describe()
# Out:
#         valor_venta
# count     30.000000
# mean   48903.117333
# std    13265.561715
# min    11128.800000
# 25%    45601.920000
# 50%    48140.245000
# 75%    51092.960000
# max    82276.380000

# %%
# Agrego un plot para visualizar graficamente la distribución
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(tabla_ventas["valor_venta"], bins=30, kde=True, edgecolor="black")
plt.title("Distribución de Valor de Venta con Curva de Densidad")
plt.xlabel("Valor de venta")
plt.ylabel("Frecuencia")
plt.show()

# %%
# Calculo el percentil 75 (umbral de alto rendimiento)
umbral_ventas = tabla_ventas["valor_venta"].quantile(0.75)
umbral_ventas
# Out:
# np.float64(51092.96)

# %%
# Identifico los productos que superan el umbral
productos_top = tabla_ventas.query("valor_venta >= @umbral_ventas")
# productos_top = tabla_ventas[tabla_ventas["valor_venta"] >= umbral_ventas]
productos_top
# Out:
#              producto  valor_venta
# 3         Auriculares     74175.58
# 5            Cafetera     59607.31
# 9   Cuadro decorativo     54297.60
# 16  Jarrón decorativo     51130.88
# 19    Lámpara de mesa     82276.38
# 20         Microondas     72562.89
# 25           Secadora     52115.45
# 27         Smartphone     54132.44

# %% [markdown]
# ## Agregación
# Actividad 3 - Resumir las ventas por categoría de producto y analizar los ingresos generados.

# %%
# Veo las columnas del dataframe
df_ventas.columns
# Out:
# Index(['id_venta', 'producto', 'precio', 'cantidad', 'fecha_venta',
#        'categoria', 'valor_venta'],
#       dtype='object')

# %%
# Veo las diferentes categorías que hay
df_ventas["categoria"].unique()
# Out:
# <StringArray>
# ['Decoración', 'Electrodomésticos', 'Electrónica']
# Length: 3, dtype: string

# %%
# Agrupo por categoria y agrego la suma de las ventas. Genero un nuevo dataframe ventas_categoria.
ventas_categoria = df_ventas.groupby("categoria")["valor_venta"].sum().reset_index()
ventas_categoria
# Out:
#            categoria  valor_venta
# 0         Decoración    479216.09
# 1  Electrodomésticos    505299.63
# 2        Electrónica    482577.80

# %%
# Ordeno por valor_venta de mayor a menor y muestro los resultados
print (color.BOLD + "--- Total de ventas por categoría ---" + color.END)
ventas_categoria.sort_values(by="valor_venta", ascending=False)
# Out:
# --- Total de ventas por categoría ---
#            categoria  valor_venta
# 1  Electrodomésticos    505299.63
# 2        Electrónica    482577.80
# 0         Decoración    479216.09

# %%
# Muestro los resultados en un gráfico de barras
# -- Los imports de seaborn (sns) y matplotlib.pyplot (plt) ya están en el gráfico anterior

# Ajusto el tamaño de la figura
plt.figure(figsize=(6, 4))

# Un color distinto por categoría, y sin recuadro descriptivo de detalle de color para cada categoría (leyenda)
sns.barplot(x='categoria', y='valor_venta', data=ventas_categoria, hue="categoria", palette='bright', legend=False)

plt.title('Total de Ventas por Categoría')
plt.xlabel('Categoría')
plt.ylabel('Valor Venta')

# Evito que se superpongan los elementos
plt.tight_layout()

plt.show()

# %% [markdown]
# ## Integración de datos
# Actividad 4 - Combinar los sets de datos de ventas y marketing para obtener una visión más amplia de las tendencias.

# %%
# Examino los primeros 2 registros del dataset de ventas
df_ventas.head(2)
# Out:
#    id_venta           producto  precio  cantidad fecha_venta   categoria  \
# 0       792  Cuadro decorativo   69.94         5  2024-01-02  Decoración
# 1       811    Lámpara de mesa  105.10         5  2024-01-02  Decoración
#
#    valor_venta
# 0        349.7
# 1        525.5

# %%
# Aplico info() para obtener información del dataframe de marketing
df_marketing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id_campanha   90 non-null     int64
#  1   producto      90 non-null     string
#  2   canal         90 non-null     string
#  3   costo         90 non-null     float64
#  4   fecha_inicio  90 non-null     datetime64[ns]
#  5   fecha_fin     90 non-null     datetime64[ns]
# dtypes: datetime64[ns](2), float64(1), int64(1), string(2)
# memory usage: 4.3 KB

# %% [markdown]
# ### Unión de los dataframes de ventas y marketing

# %%
# Veo que en ambos datasets está la columna 'producto'. Los uno entonces por esa columna.
# Veo que la cantidad de registros se triplicó, esto se debe a que hay 3 campañas de marketing (RSS, TV, Email) por cada producto
ventas_marketing = pd.merge(df_ventas, df_marketing, on="producto", how="left")
print("Cantidad de registros: ", len(ventas_marketing))
# Out:
# Cantidad de registros:  8994

# %%
# Veo algunos registros luego del merge (ordenados por producto, id_venta)
ventas_marketing[["id_venta","producto","canal","cantidad","precio","valor_venta","costo","fecha_venta","fecha_inicio","fecha_fin"]].sort_values(by=["producto", "id_venta"], ascending=True).head(6)
# Out:
#       id_venta         producto  canal  cantidad  precio  valor_venta  costo  \
# 4602        10  Adorno de pared     TV        10   44.65       446.50   4.81
# 4603        10  Adorno de pared  Email        10   44.65       446.50   5.08
# 4604        10  Adorno de pared   RRSS        10   44.65       446.50   4.16
# 303         20  Adorno de pared     TV         2   90.21       180.42   4.81
# 304         20  Adorno de pared  Email         2   90.21       180.42   5.08
# 305         20  Adorno de pared   RRSS         2   90.21       180.42   4.16
#
#      fecha_venta fecha_inicio  fecha_fin
# 4602  2024-06-29   2024-03-20 2024-05-03
# 4603  2024-06-29   2024-04-13 2024-05-10
# 4604  2024-06-29   2024-10-22 2024-12-21
# 303   2024-01-14   2024-03-20 2024-05-03
# 304   2024-01-14   2024-04-13 2024-05-10
# 305   2024-01-14   2024-10-22 2024-12-21

# %%
# Veo algunos registros luego del merge, pero ordenados por fecha_venta
ventas_marketing[["id_venta","producto", "valor_venta", "canal", "costo", "fecha_venta", "fecha_inicio","fecha_fin"]].sort_values(by=["valor_venta"], ascending=False).head(6)
# Out:
#       id_venta    producto  valor_venta  canal  costo fecha_venta  \
# 1646      2063  Smartphone      1488.12     TV   4.78  2024-03-05
# 1644      2063  Smartphone      1488.12   RRSS   6.37  2024-03-05
# 1645      2063  Smartphone      1488.12  Email   4.65  2024-03-05
# 2625      1109    Batidora      1485.96  Email   4.48  2024-04-11
# 2627      1109    Batidora      1485.96   RRSS   4.52  2024-04-11
# 2626      1109    Batidora      1485.96     TV   6.28  2024-04-11
#
#      fecha_inicio  fecha_fin
# 1646   2024-09-28 2024-10-24
# 1644   2024-03-29 2024-05-16
# 1645   2024-05-28 2024-06-15
# 2625   2024-04-10 2024-06-08
# 2627   2024-11-01 2024-12-08
# 2626   2024-08-27 2024-10-11

# %% [markdown]
# **Luego del merge se encuentra:**
#
# **Aparecen ventas triplicadas por el hecho de que hay 3 campañas de marketing (RSS, TV, Email) por cada producto.**
# En la vista anterior se ven los primeros 3 registros con id_venta 2063, pero encima en ese caso el producto fue vendido el 5/3/24, fuera de los 3 períodos de marketing para ese producto.
# Y en el caso de los últimos 3 registros con id_venta 1109, dos de ellos fuera, y uno dentro de los 3 períodos de marketing.
# Por ello, voy a generar dos nuevos dataframes, uno con las ventas dentro del período de marketing, y otro con las ventas fuera del período.

# %% [markdown]
# ### Ventas dentro de la campaña (opción con map, y opción con filtro, agrupación y agregación)

# %%
# Agrego con map una columna "en_campaña" SI o NO en ventas_marketing
ventas_marketing['en_campaña'] = (
    (ventas_marketing['fecha_venta'] >= ventas_marketing['fecha_inicio']) &
    (ventas_marketing['fecha_venta'] <= ventas_marketing['fecha_fin'])
).map({True: "SI", False: "NO"})

# %%
# Veo cómo quedó con algunas filas de ejemplo
ventas_marketing[["id_venta","producto","fecha_venta","fecha_inicio","fecha_fin","en_campaña"]].sample(10)
# Out:
#       id_venta                producto fecha_venta fecha_inicio  fecha_fin  \
# 5485       372       Cuadro decorativo  2024-08-04   2024-08-15 2024-09-12
# 7775       217   Elementos de cerámica  2024-11-11   2024-09-09 2024-09-30
# 2636      2478              SmartWatch  2024-04-11   2024-11-23 2024-12-29
# 4251      2859               Proyector  2024-06-11   2024-05-22 2024-07-12
# 7843      1566                Secadora  2024-11-14   2024-11-03 2024-11-28
# 2580       426                Cortinas  2024-04-10   2024-05-02 2024-06-17
# 5615       295                Alfombra  2024-08-10   2024-11-27 2025-01-08
# 4701      2906                  Laptop  2024-07-02   2024-09-28 2024-10-27
# 7069      1133              Microondas  2024-10-10   2024-09-25 2024-10-14
# 535       2560  Consola de videojuegos  2024-01-21   2024-07-15 2024-08-03
#
#      en_campaña
# 5485         NO
# 7775         NO
# 2636         NO
# 4251         SI
# 7843         SI
# 2580         NO
# 5615         NO
# ...

# %%
# Veo el total de cada uno
ventas_marketing["en_campaña"].value_counts()
# Out:
# en_campaña
# NO    8147
# SI     847
# Name: count, dtype: int64

# %%
# Filtro solo aquellos productos que se hayan vendido dentro de una campaña de marketing
# ventas_con_marketing = ventas_marketing.query("en_campaña == 'SI'")
ventas_con_marketing = ventas_marketing.query("fecha_venta >= fecha_inicio & fecha_venta <= fecha_fin")
print("Cantidad de registros dentro de la campaña: ", len(ventas_con_marketing))
# Out:
# Cantidad de registros dentro de la campaña:  847

# %%
# Visualizo algunos de los registros de ventas durante la campaña de marketing
ventas_con_marketing[["id_venta","producto", "valor_venta", "canal", "costo", "fecha_venta", "fecha_inicio","fecha_fin"]].sort_values(by=["producto", "id_venta"], ascending=True).head(6)
# Out:
#       id_venta         producto  valor_venta  canal  costo fecha_venta  \
# 7937        70  Adorno de pared      1265.04   RRSS   4.16  2024-11-18
# 3195       100  Adorno de pared       897.28     TV   4.81  2024-05-02
# 3196       100  Adorno de pared       897.28  Email   5.08  2024-05-02
# 8450       130  Adorno de pared       206.10   RRSS   4.16  2024-12-08
# 7508       190  Adorno de pared       360.80   RRSS   4.16  2024-10-30
# 2160       210  Adorno de pared       286.68     TV   4.81  2024-03-24
#
#      fecha_inicio  fecha_fin
# 7937   2024-10-22 2024-12-21
# 3195   2024-03-20 2024-05-03
# 3196   2024-04-13 2024-05-10
# 8450   2024-10-22 2024-12-21
# 7508   2024-10-22 2024-12-21
# 2160   2024-03-20 2024-05-03

# %%
# Como hay duplicados, listo solo esos
ventas_con_marketing_duplicados = ventas_con_marketing[ventas_con_marketing.duplicated(subset="id_venta",keep=False)]
ventas_con_marketing_duplicados[["id_venta","producto", "valor_venta", "canal", "costo", "fecha_venta", "fecha_inicio","fecha_fin"]].sort_values(by=["producto", "id_venta"], ascending=True).head(6)
# Out:
#       id_venta         producto  valor_venta  canal  costo fecha_venta  \
# 3195       100  Adorno de pared       897.28     TV   4.81  2024-05-02
# 3196       100  Adorno de pared       897.28  Email   5.08  2024-05-02
# 3237       220  Adorno de pared       498.24     TV   4.81  2024-05-03
# 3238       220  Adorno de pared       498.24  Email   5.08  2024-05-03
# 2985       320  Adorno de pared       224.28     TV   4.81  2024-04-25
# 2986       320  Adorno de pared       224.28  Email   5.08  2024-04-25
#
#      fecha_inicio  fecha_fin
# 3195   2024-03-20 2024-05-03
# 3196   2024-04-13 2024-05-10
# 3237   2024-03-20 2024-05-03
# 3238   2024-04-13 2024-05-10
# 2985   2024-03-20 2024-05-03
# 2986   2024-04-13 2024-05-10

# %% [markdown]
# **Aclaración** : los registros con id_venta duplicados nos impiden agrupar directamente por producto, debemos antes agrupar por [id_venta, producto] quedarnos con el primer valor_venta y hacer la suma de los costos de marketing.
# Luego sí agrupamos por producto, para saber el monto total de venta para cada uno.

# %%
# Agrupo primero por id_venta y producto
# De esa partición, me quedo con la primer venta y la suma de los costos de marketing
ventas_con_marketing_agg1 = ventas_con_marketing.groupby(["id_venta","producto"], as_index=False).agg(
    valor_venta=("valor_venta", "first"),
    costo_agg=("costo", "sum")
)

print("Cantidad de registros con id_venta únicos: ", len(ventas_con_marketing_agg1))
# Out:
# Cantidad de registros con id_venta únicos:  768

# %%
# Verifico la consistencia de los montos, ventas y costos de marketing
ventas_con_marketing_agg1[["id_venta","producto", "valor_venta", "costo_agg"]].sort_values(by=["producto", "id_venta"], ascending=True).head(6)
# Out:
#     id_venta         producto  valor_venta  costo_agg
# 20        70  Adorno de pared      1265.04       4.16
# 30       100  Adorno de pared       897.28       9.89
# 39       130  Adorno de pared       206.10       4.16
# 56       190  Adorno de pared       360.80       4.16
# 61       210  Adorno de pared       286.68       4.81
# 64       220  Adorno de pared       498.24       9.89

# %%
# En la segunda agregacion, agrupo solo por producto
ventas_con_marketing_agg2 = ventas_con_marketing_agg1.groupby(["producto"], as_index=False).agg(
    ventas_producto_cm=("valor_venta", "sum"),
    costo_marketing=("costo_agg", "sum")
)

# Agrego otra columna con la ganancia
ventas_con_marketing_agg2["ganacia_producto_cm"]= ventas_con_marketing_agg2["ventas_producto_cm"]-ventas_con_marketing_agg2["costo_marketing"]

# Finalmente, ordeno y guardo en el dataframe final
ventas_con_marketing_final = ventas_con_marketing_agg2.sort_values(by=["ganacia_producto_cm"], ascending=False)

# %%
# Dataframe resultante
ventas_con_marketing_final.head(5)
# Out:
#                producto  ventas_producto_cm  costo_marketing  \
# 4              Batidora            23460.35           227.32
# 9     Cuadro decorativo            19293.71           195.51
# 3           Auriculares            18181.01           212.75
# 21  Parlantes Bluetooth            17942.96           144.45
# 19      Lámpara de mesa            17925.37           235.19
#
#     ganacia_producto_cm
# 4              23233.03
# 9              19098.20
# 3              17968.26
# 21             17798.51
# 19             17690.18

# %% [markdown]
# ### Ventas fuera de la campaña de marketing

# %%
# Filtramos solo aquellos productos que se hayan vendido fuera de la campaña
# ventas_sin_marketing = ventas_marketing.query("en_campaña == 'NO'")
ventas_sin_marketing = ventas_marketing.query("(fecha_venta < fecha_inicio) | (fecha_venta > fecha_fin)")
print("Cantidad de registros fuera de la campaña: ", len(ventas_sin_marketing))
# Out:
# Cantidad de registros fuera de la campaña:  8147

# %%
# Visualizo algunos de los registros de ventas fuera de la campaña de marketing
ventas_sin_marketing[["id_venta","producto", "valor_venta", "fecha_venta", "fecha_inicio","fecha_fin"]].sort_values(by=["id_venta","producto"], ascending=True).head(6)
# Out:
#       id_venta           producto  valor_venta fecha_venta fecha_inicio  \
# 2794         1    Lámpara de mesa       658.00  2024-04-17   2024-05-30
# 2795         1    Lámpara de mesa       658.00  2024-04-17   2024-08-26
# 1458         2  Cuadro decorativo       318.36  2024-02-27   2024-04-27
# 1459         2  Cuadro decorativo       318.36  2024-02-27   2024-08-15
# 1460         2  Cuadro decorativo       318.36  2024-02-27   2024-11-05
# 6630         3  Espejo decorativo        51.32  2024-09-22   2024-05-31
#
#       fecha_fin
# 2794 2024-06-29
# 2795 2024-10-07
# 1458 2024-06-04
# 1459 2024-09-12
# 1460 2024-12-23
# 6630 2024-07-08

# %%
# Acá también hay id_venta duplicados, así que procedo igual que antes, agrupando primero por id_venta y producto
# y luego solo por producto
ventas_sin_marketing_agg1 = ventas_sin_marketing.groupby(["id_venta", "producto"], as_index=False).agg(
    valor_venta=("valor_venta", "first")
)
print(len(ventas_sin_marketing_agg1))

ventas_sin_marketing_agg2 = ventas_sin_marketing_agg1.groupby(["producto"], as_index=False).agg(
    ventas_producto_sm=("valor_venta", "sum")
)

# Ordeno y guardo en el dataframe final
ventas_sin_marketing_final = ventas_sin_marketing_agg2[["producto", "ventas_producto_sm"]].sort_values(by=["ventas_producto_sm"], ascending=False)
# Out:
# 2998

# %%
ventas_sin_marketing_final.head(5)
# Out:
#              producto  ventas_producto_sm
# 19    Lámpara de mesa            82276.38
# 3         Auriculares            74175.58
# 20         Microondas            72562.89
# 5            Cafetera            59607.31
# 9   Cuadro decorativo            54297.60

# %% [markdown]
# ### Grafico apilado de ventas y costos de marketing

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Crear un gráfico de barras apilado para comparar valor_venta y costo por producto

# Estilos
sns.set_theme(
    style="whitegrid",
    palette="Set2",
    context="notebook")
plt.figure(figsize=(10,6))

# Primer nivel (abajo)
plt.bar(ventas_con_marketing_final["producto"], ventas_con_marketing_final["ventas_producto_cm"], label="Ventas")

# Segundo nivel (arriba)
plt.bar(ventas_con_marketing_final["producto"], ventas_con_marketing_final["costo_marketing"],
        bottom=ventas_con_marketing_final["ventas_producto_cm"],
        label="Costo Marketing")


plt.xticks(rotation=90, fontsize=8)
plt.yticks(fontsize=8)
plt.show()

# %% [markdown]
# # Entrega Final

# %% [markdown]
# # Etapa 3 - Análisis de Datos

# %% [markdown]
# Objetivo: Realizar análisis estadístico y exploratorio sobre los datos procesados, sobre:
#
#
# *   df_ventas
# *   df_marketing

# %% [markdown]
# ## 1 - Estadística Descriptiva

# %% [markdown]
# Calcular medidas de tendencia central y dispersión sobre las ventas. Presentar los resultados en un informe.

# %% [markdown]
# En la Etapa 2 - Limpieza de datos, obtuvimos los dataframes:
#
# *   df_ventas
# *   df_marketing
#
# Usamos el método describe para obtener un resumen de las:
#
# *   Medidas de posición
# *   Medidas de dispersión o variabilidad

# %%
# Dataframe ventas
df_ventas[["precio", "cantidad", "valor_venta"]].describe()
# Out:
#             precio     cantidad  valor_venta
# count  2998.000000  2998.000000  2998.000000
# mean     75.291318     6.502668   489.357412
# std      28.736008     3.455107   334.281817
# min      26.000000     1.000000    26.300000
# 25%      50.030000     3.000000   220.920000
# 50%      75.205000     7.000000   418.065000
# 75%     100.067500     9.000000   709.920000
# max     124.970000    12.000000  1488.120000

# %%
df_marketing.head()
# Out:
#    id_campanha         producto  canal  costo fecha_inicio  fecha_fin
# 0           74  Adorno de pared     TV   4.81   2024-03-20 2024-05-03
# 1           12           Tablet   RRSS   3.40   2024-03-26 2024-05-13
# 2           32  Lámpara de mesa  Email   5.54   2024-03-28 2024-04-20
# 3           21       Smartphone   RRSS   6.37   2024-03-29 2024-05-16
# 4           58         Alfombra  Email   4.25   2024-03-31 2024-05-05

# %%
# Dataframe marketing
df_marketing.groupby("canal")["costo"].describe()
# Out:
#        count      mean       std   min     25%    50%     75%   max
# canal
# Email   30.0  4.840000  0.898773  2.95  4.2125  4.895  5.5075  6.84
# RRSS    30.0  5.030333  0.894101  3.16  4.5600  5.130  5.5425  7.16
# TV      30.0  4.915667  1.063215  3.06  4.3725  4.795  5.5400  7.39

# %% [markdown]
# ## 2 - EDA (Análisis Exploratorio de Datos)

# %% [markdown]
# Realizar un análisis exploratorio utilizando visualizaciones para identificar patrones y tendencias en las ventas.

# %% [markdown]
# ### Gráficos histogramas

# %%
# Histograma de precios

# Estilo y tamaños
sns.set_theme(style="darkgrid", palette="muted") # deep, muted, bright, Set1, Set2, Set3
plt.figure(figsize=(10, 6))

# Grafico
sns.histplot(data=df_ventas, x="precio", bins="auto", kde=True)

# Títulos y leyendas
plt.title("Histograma de Precios")
plt.xlabel("Precio")
plt.ylabel("Frecuencia")
plt.show()

# %%
# Histograma de cantidades

# Estilo y tamaños
sns.set_theme(style="whitegrid", palette="deep") # deep, muted, bright, Set1, Set2, Set3
plt.figure(figsize=(10, 6))

# Grafico
sns.histplot(data=df_ventas, x="cantidad", bins="auto", kde=True)

# Títulos y leyendas
plt.title("Histograma de Cantidades")
plt.xlabel("Cantidad")
plt.ylabel("Frecuencia")
plt.show()

# %%
# Histograma de ventas_totales

# Estilo y tamaños
sns.set_theme(style="ticks", palette="deep") # deep, muted, bright, Set1, Set2, Set3
plt.figure(figsize=(10, 6))

# Grafico
sns.histplot(data=df_ventas, x="valor_venta", bins="auto", kde=True)

# Títulos y leyendas
plt.title("Histograma de Ventas Totales")
plt.xlabel("Ventas")
plt.ylabel("Frecuencia")
plt.show()

# %%
# Histograma de costo marketing

# Estilo y tamaños
sns.set_theme(style="darkgrid", palette="colorblind") # deep, muted, bright, Set1, Set2, Set3
plt.figure(figsize=(10, 6))

# Grafico
sns.histplot(data=df_marketing, x="costo", bins="auto", kde=True)

# Títulos y leyendas
plt.title("Histograma de Costos de Marketing")
plt.xlabel("Costo")
plt.ylabel("Frecuencia")
plt.show()

# %% [markdown]
# ### Gráficos Boxplot

# %%
# Boxplot de Ventas

# Estilo y tamaños
sns.set_theme(style="darkgrid", palette="deep") # deep, muted, bright, Set1, Set2, Set3
plt.figure(figsize=(12, 6)) #ancho x alto = resolucion

# Subplots, dividen al lienzo en partes

# Subplot 1
plt.subplot(1,3,1) # (1 fila, 3 columans, bloque 1)
sns.boxplot(data=df_ventas, y="precio")
plt.title("Boxplot de Precios")
plt.ylabel("")

# Subplot 2
plt.subplot(1,3,2) # (1 fila, 3 columans, bloque 2)
sns.boxplot(data=df_ventas, y="valor_venta")
plt.title("Boxplot de Valor de venta")
plt.ylabel("")

# Subplot 3
plt.subplot(1,3,3) # (1 fila, 3 columans, bloque 3)
sns.boxplot(data=df_ventas, y="cantidad")
plt.title("Boxplot de Cantidad")
plt.ylabel("")

plt.show()

# %%
# Boxplot de marketing

# Estilo y tamaños
sns.set_theme(style="whitegrid", palette="Set3") # deep, muted, bright, Set1, Set2, Set3
plt.figure(figsize=(12, 6))

# Grafico
sns.boxplot(data=df_marketing, x="canal", y="costo")
# sns.boxplot(data=df_marketing, y="costo") # asi grafico costo para todos los canales

# Título y subtítulo
plt.title("Distribución del Costo por Canal de Marketing", fontsize=16, pad=15)

plt.xlabel("Canales de Marketing", fontsize=12)
plt.ylabel("")

# Rotación y tamaño de labels del eje X
plt.xticks(rotation=45, fontsize=10)

plt.show()

# %% [markdown]
# ## 3 - Correlación

# %%
# Primero calculo la matríz de correlación usando las variables numéricas
correlacion = df_ventas[['precio', 'cantidad', 'valor_venta']].corr()  # calcula la matriz de correlacion
print("\nMatriz de correlación:")
print(correlacion)
# Out:
# Matriz de correlación:
#                precio  cantidad  valor_venta
# precio       1.000000 -0.002388     0.558846
# cantidad    -0.002388  1.000000     0.773009
# valor_venta  0.558846  0.773009     1.000000

# %%
# Represento las variables en un scatterplot o gráfico de dispersión
# Y agrego una línea de tendencia

plt.figure(figsize=(10,5))

# precio y valor_venta
plt.subplot(1,2,1)
plt.title("Relación precio y valor_venta")
sns.scatterplot(data=df_ventas, x="precio", y="valor_venta")
# agrega una linea de regresion
sns.regplot(
    data=df_ventas,
    x="precio",
    y="valor_venta",
    color="steelblue",
    line_kws={"color": "darkred", "label": "Recta de regresión"}
)

# cantidad y valor_venta
plt.subplot(1,2,2)
plt.title("Relación cantidad y valor_venta")
sns.scatterplot(data=df_ventas, x="cantidad", y="valor_venta")
sns.regplot(
    data=df_ventas,
    x="cantidad",
    y="valor_venta",
    color="steelblue",
    line_kws={"color": "darkred", "label": "Recta de regresión"}
)

# Los distribuyo para que no se peguen
plt.tight_layout()

plt.show()

# %%
# Creo un mapa de calor para representar la matríz de correlación
sns.heatmap(correlacion, annot=True, cmap="rocket")   # Blues, Greens, rocket
plt.show()

# %% [markdown]
# ## 4 - Consolidación de datos

# %% [markdown]
# Consolidar todos los análisis previos y preparar un conjunto de datos final que resuma los hallazgos clave para la presentación.
#
# Aquí intervienen los KPIs, esto es, cuáles son las métricas que le interesan al negocio.
# KPIs:
#
#
# *   Importe total de ventas concretado por mes
# *   Cantidad de productos totales vendidos por mes
# *   Volumen de venta por categorías
# *   Impacto de las campañas de marketing en las ventas
#
# ### Importe total de ventas concretado por mes

# %%
# Corro un head para recordar el dataframe
df_ventas.head(10)
# Out:
#    id_venta           producto  precio  cantidad fecha_venta  \
# 0       792  Cuadro decorativo   69.94         5  2024-01-02
# 1       811    Lámpara de mesa  105.10         5  2024-01-02
# 2      1156           Secadora   97.96         3  2024-01-02
# 3      1372           Heladera  114.35         8  2024-01-02
# 4      1546           Secadora  106.21         4  2024-01-02
# 5      1697    Horno eléctrico   35.35         9  2024-01-02
# 6      1710   Plancha de vapor   65.43         2  2024-01-02
# 7      2959          Proyector   88.17         9  2024-01-02
# 8       318  Rincón de plantas   79.86        11  2024-01-03
# 9       419         Candelabro   66.11         8  2024-01-03
#
#            categoria  valor_venta
# 0         Decoración       349.70
# 1         Decoración       525.50
# 2  Electrodomésticos       293.88
# 3  Electrodomésticos       914.80
# 4  Electrodomésticos       424.84
# 5  Electrodomésticos       318.15
# 6  Electrodomésticos       130.86
# ...

# %%
# Genero la columna mes ya que el dataframe no la trae por separado
df_ventas["mes"] = df_ventas["fecha_venta"].dt.month

# Agrupo por mes y agrego valor_venta
ventas_mes = df_ventas.groupby("mes", as_index=False).agg(
    ventas_mes=("valor_venta", "sum")
)

# Renombro la columna si fuera necesario
# ventas_mes = ventas_mes.rename(columns={
#     "mes": "mes",
#     "ventas_mes": "ventas_totales"
# })

# Visualizo
ventas_mes.head()
# Out:
#    mes  ventas_mes
# 0    1   129604.99
# 1    2   118672.44
# 2    3   136779.15
# 3    4   128430.69
# 4    5   143727.25

# %%
# Genero un gráfico de lineas (serie de tiempo)
# para mostrar la evolución de las ventas por mes en el año 2024
import matplotlib.pyplot as plt
import seaborn as sns

# Estilo
sns.set_theme(style="whitegrid", context="talk")
# custom_palette = sns.color_palette("Set1")   # "Set1", "Set2", "Set3"
# sns.palplot(custom_palette)

# Tamaño del lienzo
plt.figure(figsize=(10,6))

# Grafico
sns.lineplot(data=ventas_mes, x="mes", y="ventas_mes", label="Ventas mesuales", color="orange", linewidth=5 )

# Ticks (valores de eje)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Ajustes de título y ejes
titulo = plt.title('Ventas mensuales sin marca de inicio de campaña', fontsize=15, color="orange", fontweight="bold")
# Aplico efecto de sombra al título
titulo.set_path_effects([
    path_effects.withSimplePatchShadow(offset=(1.5, -1.5), shadow_rgbFace='black'),
    path_effects.Normal()
])
plt.xlabel('Mes', fontsize=12)
plt.ylabel('Ventas Acumuladas', fontsize=12)
plt.legend(title='Año', fontsize=10, title_fontsize=11)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Cantidad de productos totales vendidos por mes (gráfico de barras y Nightingale Rose)

# %%
# Agrupo por mes y agrego por cantidad
cantidades_mes = df_ventas.groupby("mes", as_index=False).agg(
    cantidad_mes=("cantidad", "sum")
)

# Visualizo
cantidades_mes.head()
# Out:
#    mes  cantidad_mes
# 0    1          1741
# 1    2          1607
# 2    3          1792
# 3    4          1715
# 4    5          1812

# %%
# Para efecto de sombra agregado al título
import matplotlib.patheffects as path_effects

# Estilo y paleta
sns.set_theme(               # set_theme combina estilo + contexto + paleta
    style="whitegrid",       # opciones: 'white', 'whitegrid', 'dark', 'darkgrid', 'ticks'
    context="notebook",      # escala general: 'paper', 'notebook', 'talk', 'poster'
    palette="Set2"           # paleta de colores base: "deep", "muted", "pastel" / Set1, Set2, Set3
)

# Ajustamos tamaño del lienzo
plt.figure(figsize=(10,6))

# Creo el barplot
ax = sns.barplot(data=cantidades_mes, x='mes', y='cantidad_mes', label="Ventas 2024", width=0.8)

# Agrego etiquetas arriba de las barras
for i, valor in enumerate(cantidades_mes['cantidad_mes']):
    ax.text(
        i,                       # posición x de la etiqueta
        valor + 10,              # posición y (ligeramente arriba de la barra)
        str(valor),              # texto
        ha='center', fontsize=10
    )

# Ticks (valores de eje)
plt.tick_params(axis='y', labelsize=11)
plt.tick_params(axis='x', rotation=45,  labelsize=11)

# Ajustes de título
titulo = plt.title('Volúmenes de ventas por productos', fontsize=15)

# Aplico efecto de sombra al título
titulo.set_path_effects([
    path_effects.withSimplePatchShadow(offset=(2, -2), shadow_rgbFace='gray'),
    path_effects.Normal()
])

# Ajuste de  ejes
plt.xlabel('Mes')
plt.ylabel('Cantidades')
plt.legend(loc='upper right', fontsize=9)

# plt.tight_layout() # ajuste automatico
plt.show()

# %%
# Nightingale Rose
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

def nightingale_rose(df, col_categoria="mes", col_valor="cantidades_mes",
                     title="Nightingale Rose Diagram"):
    """
    df: DataFrame ordenado con dos columnas
    col_categoria: nombre de la columna de categorías
    col_valor: nombre de la columna numérica
    """

    categorias = df[col_categoria].tolist()
    valores = df[col_valor].tolist()

    N = len(df)                           # número de filas del df
    angles = np.linspace(0, 2*np.pi, N, endpoint=False)

    # Paleta automática (tab20 soporta hasta 20 colores, tab20b + tab20c permiten más)
    if N <= 15:
        colors = plt.cm.tab20(np.linspace(0, 1, N))
    else:
        # Para más de 20 categorías, usamos una paleta continua
        colors = plt.cm.viridis(np.linspace(0, 1, N))

    plt.figure(figsize=(8, 8))
    ax = plt.subplot(111, polar=True)

    # Barras
    ax.bar(
        angles,
        valores,
        width=2 * np.pi / N,
        bottom=0,
        color=colors,
        edgecolor="white",
        linewidth=1
    )

    # Etiquetas
    for angle, value, label in zip(angles, valores, categorias):
        ax.text(
            angle,
            value + (max(valores) * 0.05),
            f"{label}\n{value}",
            ha="center",
            va="center",
            fontsize=12,
            color="black",
            fontweight="bold"
        )

    # Limpieza estética
    ax.set_yticklabels([])
    ax.set_theta_offset(np.pi / 2)
    ax.set_theta_direction(-1)

    plt.title(title, fontsize=16, pad=40)
    plt.show()

# %%
# Mismo gráfico pero con Nightingale Rose
#nightingale_rose(ventas_categoria, "categoria", "ventas_totales",
#                 title="Nightingale Rose Diagram – Volúmenes de ventas por categoría")
nightingale_rose(cantidades_mes, "mes", "cantidad_mes",
                 title="Nightingale Rose Diagram – Volúmenes de ventas por productos")

# %% [markdown]
# ### Volumen de venta por categorías

# %%
df_ventas.head()
# Out:
#    id_venta           producto  precio  cantidad fecha_venta  \
# 0       792  Cuadro decorativo   69.94         5  2024-01-02
# 1       811    Lámpara de mesa  105.10         5  2024-01-02
# 2      1156           Secadora   97.96         3  2024-01-02
# 3      1372           Heladera  114.35         8  2024-01-02
# 4      1546           Secadora  106.21         4  2024-01-02
#
#            categoria  valor_venta  mes
# 0         Decoración       349.70    1
# 1         Decoración       525.50    1
# 2  Electrodomésticos       293.88    1
# 3  Electrodomésticos       914.80    1
# 4  Electrodomésticos       424.84    1

# %%
# Agrupo por categoría y agrego por valor_venta
ventas_categoria = df_ventas.groupby("categoria", as_index=False).agg(
    ventas_totales=("valor_venta", "sum")
)

# Visualizamos
ventas_categoria.head()
# Out:
#            categoria  ventas_totales
# 0         Decoración       479216.09
# 1  Electrodomésticos       505299.63
# 2        Electrónica       482577.80

# %%
# Estilo y paleta
sns.set_theme(               # set_theme combina estilo + contexto + paleta
    style="whitegrid",       # opciones: 'white', 'whitegrid', 'dark', 'darkgrid', 'ticks'
    context="notebook",      # escala general: 'paper', 'notebook', 'talk', 'poster'
    palette="Set2"           # paleta de colores base: "deep", "muted", "pastel" / Set1, Set2, Set3
)

# Ajusto el tamaño del lienzo
plt.figure(figsize=(9,5))

# Creo el barplot
colores = ["#FF0000", "#FF7F00", "#FFFF00"]
ax = sns.barplot(data=ventas_categoria, x='categoria', y='ventas_totales', label="Ventas por categoría", width=0.5, hue='categoria', palette=colores)

# Ticks (valores de eje)
plt.tick_params(axis='y', labelsize=9)
plt.tick_params(axis='x', labelsize=10)

# Ajustes de título y ejes
plt.title('Volúmenes de ventas por categoría', fontsize=14, fontweight="semibold")
plt.xlabel('Categorías')
plt.ylabel('Total de ventas')

# plt.legend(loc='upper right', fontsize=10)
# plt.tight_layout() # ajuste automatico

plt.show()

# %% [markdown]
# ### Impacto de la campaña de marketing en las ventas I

# %% [markdown]
# Trazo una línea vertical al primer gráfico ventas por mes para visualizar cuándo comenzó la campaña

# %%
# Genero un gráfico de lineas (serie de tiempo)
# que muestre la evolución de las ventas por mes en el año 2024
import matplotlib.pyplot as plt
import seaborn as sns

# Estilo
sns.set_theme(style="whitegrid", context="talk")
custom_palette = sns.color_palette("Set2") # Aqui pueden cambiar a "Set1", "Set2", "Set3"

# Defino el tamaño del lienzo
plt.figure(figsize=(10,6))

# Grafico
sns.lineplot(data=ventas_mes, x="mes", y="ventas_mes", label="Ventas mesuales", marker='s')

# Línea vertical que marque el inicio de campaña
plt.axvline(4, color="red", linewidth=2, linestyle="--",
            label="Inicio de campaña")

# Ticks (valores de eje)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)

# Agregar etiquetas de texto sobre/bajo cada marcador
anterior = 0
posicion_y = 0
for i, row in ventas_mes.iterrows():

    if (anterior < row['ventas_mes']):
       posicion_y = 500
    else:
       posicion_y = -1800

    anterior = row['ventas_mes']

    plt.text(
        row['mes'],                      # posición en eje X
        row['ventas_mes'] + posicion_y,  # posición en eje Y (un poco arriba/abajo del punto)
        f"{row['ventas_mes']}",          # texto a mostrar
        ha='center',                     # alineación horizontal centrada
        va='bottom',                     # alineación vertical (debajo o encima del punto)
        fontsize=10,
        color='gray',
        fontweight='bold'
    )

# Ajustes de título y ejes
plt.title('Ventas mensuales con marca de inicio de campaña', fontsize=14)
plt.xlabel('Mes', fontsize=12)
plt.ylabel('Ventas Acumuladas', fontsize=12)
plt.legend(title='Año', fontsize=10, title_fontsize=11)

# Añado cuadrícula
plt.grid(True, linestyle='--', alpha=0.6)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Impacto de la campaña de marketing en las ventas II (gráfico de barras y con Plotly)

# %% [markdown]
# Revisar la sección Etapa 2 - Integración de datos. Allí, luego de unir los dataframes df_ventas con df_marketing, se generaron 2 dataframes independientes, cada uno conteniendo las ventas que se hicieron dentro de algún período de marketing, y otro con las ventas que se realizaron fuera de campaña.
# Así surgen:
#
#
# *   ventas_con_marketing_final
# *   ventas_sin_marketing_final

# %%
# Veo algunas filas de ventas_con_marketing
ventas_con_marketing_final.head()
# Out:
#                producto  ventas_producto_cm  costo_marketing  \
# 4              Batidora            23460.35           227.32
# 9     Cuadro decorativo            19293.71           195.51
# 3           Auriculares            18181.01           212.75
# 21  Parlantes Bluetooth            17942.96           144.45
# 19      Lámpara de mesa            17925.37           235.19
#
#     ganacia_producto_cm
# 4              23233.03
# 9              19098.20
# 3              17968.26
# 21             17798.51
# 19             17690.18

# %%
# Veo algunas filas de ventas_sin_marketing
ventas_sin_marketing_final.head()
# Out:
#              producto  ventas_producto_sm
# 19    Lámpara de mesa            82276.38
# 3         Auriculares            74175.58
# 20         Microondas            72562.89
# 5            Cafetera            59607.31
# 9   Cuadro decorativo            54297.60

# %%
# Agrupo por producto los 2 dataframes en uno nuevo ventas_con_sin_marketing
ventas_con_sin_marketing = pd.merge(ventas_con_marketing_final, ventas_sin_marketing_final, on="producto", how="inner")
ventas_con_sin_marketing = ventas_con_sin_marketing.sort_values(by=["ventas_producto_cm"], ascending=False)
ventas_con_sin_marketing.head()
# Out:
#               producto  ventas_producto_cm  costo_marketing  \
# 0             Batidora            23460.35           227.32
# 1    Cuadro decorativo            19293.71           195.51
# 2          Auriculares            18181.01           212.75
# 3  Parlantes Bluetooth            17942.96           144.45
# 4      Lámpara de mesa            17925.37           235.19
#
#    ganacia_producto_cm  ventas_producto_sm
# 0             23233.03            50979.20
# 1             19098.20            54297.60
# 2             17968.26            74175.58
# 3             17798.51            47779.46
# 4             17690.18            82276.38

# %%
# Transformo a formato largo
df_long = ventas_con_sin_marketing[["producto","ventas_producto_cm", "ventas_producto_sm"]]
df_long = df_long.melt(id_vars="producto",
                        var_name="modalidad",
                        value_name="valores")
# df_long = df_long.sort_values(by=["valores", "modalidad"], ascending=True)
df_long.head()
# Out:
#               producto           modalidad   valores
# 0             Batidora  ventas_producto_cm  23460.35
# 1    Cuadro decorativo  ventas_producto_cm  19293.71
# 2          Auriculares  ventas_producto_cm  18181.01
# 3  Parlantes Bluetooth  ventas_producto_cm  17942.96
# 4      Lámpara de mesa  ventas_producto_cm  17925.37

# %%
# Para efecto de sombra agregado al título
import matplotlib.patheffects as path_effects

# Estilo y paleta
sns.set_theme(               # set_theme combina estilo + contexto + paleta
    style="whitegrid",       # opciones: 'white', 'whitegrid', 'dark', 'darkgrid', 'ticks'
    context="notebook",      # escala general: 'paper', 'notebook', 'talk', 'poster'
    palette="Set1"           # paleta de colores base: "deep", "muted", "pastel" / Set1, Set2, Set3
)

# Ajustamos el lienzo
plt.figure(figsize=(12,6))

# Grafico
sns.barplot(data=df_long, x="producto", y="valores", hue="modalidad", width=0.8)
# sns.barplot(data=df_long, x="Trimestre", y="Ventas", hue="Producto", width=0.8) # Invierto Productos por Trimestre


# Ticks (valores de eje)
plt.xticks(rotation=90, fontsize=8)
plt.yticks(fontsize=8)

# Ajustes de título
titulo = plt.title('Ventas totales por productos dentro y fuera de campaña', fontsize=18)

# Aplico efecto de sombra al título
titulo.set_path_effects([
    path_effects.withSimplePatchShadow(offset=(2, -2), shadow_rgbFace='gray'),
    path_effects.Normal()
])

# Ajuste de ejes
plt.xlabel('Productos')
plt.ylabel('Ventas')

# Obtener handles (cuadritos de color) y labels originales del gráfico
handles, labels = plt.gca().get_legend_handles_labels()

# Reemplazar solo los textos de la leyenda, manteniendo colores
plt.legend(
    handles,
    ["Fuera de campaña", "Dentro de campaña"],
    title="Modalidad",
    fontsize=9,
    title_fontsize=10
)
plt.tight_layout()

# %%
ventas_marketing.head()
# Out:
#    id_venta           producto  precio  cantidad fecha_venta   categoria  \
# 0       792  Cuadro decorativo   69.94         5  2024-01-02  Decoración
# 1       792  Cuadro decorativo   69.94         5  2024-01-02  Decoración
# 2       792  Cuadro decorativo   69.94         5  2024-01-02  Decoración
# 3       811    Lámpara de mesa  105.10         5  2024-01-02  Decoración
# 4       811    Lámpara de mesa  105.10         5  2024-01-02  Decoración
#
#    valor_venta  id_campanha  canal  costo fecha_inicio  fecha_fin en_campaña
# 0        349.7            1   RRSS   5.27   2024-04-27 2024-06-04         NO
# 1        349.7           31  Email   5.28   2024-08-15 2024-09-12         NO
# 2        349.7           61     TV   5.30   2024-11-05 2024-12-23         NO
# 3        525.5           32  Email   5.54   2024-03-28 2024-04-20         NO
# 4        525.5            2   RRSS   5.88   2024-05-30 2024-06-29         NO

# %%
# Total de valor de venta por producto
df_test = ventas_marketing.groupby(["id_venta", "producto"]).agg(
    {"valor_venta": "first"})
df_test1 = df_test.groupby("producto").agg(
    {"valor_venta": "sum"}).sort_values(by="valor_venta", ascending=False).reset_index()
df_test1.head()
# Out:
#             producto  valor_venta
# 0    Lámpara de mesa     82276.38
# 1        Auriculares     74175.58
# 2         Microondas     72562.89
# 3           Cafetera     59607.31
# 4  Cuadro decorativo     54297.60

# %%
# Visualización con Plotly
import plotly.express as px
import plotly.graph_objects as go
import ipywidgets as widgets
from IPython.display import display

# Creo una figura
fig = go.Figure()

# Añado un gráfico de barras
fig.add_trace(go.Bar(
    x=df_test1['producto'],
    y=df_test1['valor_venta'],
    name='Ventas por Producto', # Nombre para la leyenda
    marker_color='rgba(0,128,255,0.6)' # Color de las barras
))

# Actualizo el layout (título, etiquetas de ejes)
fig.update_layout(
    title='Ventas por Producto',
    xaxis_title='Producto',
    yaxis_title='Valor de Venta',
    template='plotly_white' # Opcional: cambia el tema visual
)

# Muestro el gráfico
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Mismo gráfico que el anterior, pero permito interactuar y seleccionar mediante un menú desplegable, si quiere ver todos los productos o alguno en particular
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
from IPython.display import display

# Creo el gráfico inicial (mostrando todos los datos)
fig = go.Figure(
    data=[go.Bar(
        x=df_test1['producto'],
        y=df_test1['valor_venta'],
        marker_color='skyblue'
    )]
)

# ------- Creo el menú desplegable para la selección -----

# El primer elemento es "Mostrar todos" los productos
buttons = [
    dict(
        label="Mostrar Todos",
        method="update",
        args=[
            {"y": [df_test1['valor_venta']],
             "x": [df_test1['producto']],
             "marker.color": ['skyblue']},
            {"title": "Valor de Venta por Producto (Todos)"}
        ]
    )
]

# Creo un botón para cada producto, para selección individual
for producto in df_test1['producto']:
    buttons.append(
        dict(
            label=producto,
            method="update",
            args=[
                {"y": [df_test1[df_test1['producto'] == producto]['valor_venta']],
                 "x": [df_test1[df_test1['producto'] == producto]['producto']],
                 "marker.color": ['lightblue']},
                {"title": f"Valor de Venta de {producto}"}
            ]
        )
    )
# -----------------------------------------------------

# Configuro el layout del gráfico y el update según selección
fig.update_layout(
    title_text="Ventas por Producto",
    xaxis_title="Producto",
    yaxis_title="Valor de Venta",
    xaxis={'categoryorder':'array', 'categoryarray':df_test1['producto'].tolist()},
    updatemenus=[
        dict(
            type="dropdown",
            direction="down",
            buttons=buttons,
            pad={"r": 10, "t": 10},
            showactive=True,
            x=0,
            xanchor="left",
            y=1.15,
            yanchor="top"
        )
    ]
)

# Lo muestro
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Etapa 4 - Presentación Final

# %% [markdown]
# Escribir aquí las observaciones, hallazgos y recomendaciones.

# %% [markdown]
# Se trabajó sobre un dataframe de ventas de productos en el que se encontraron algunos duplicados y datos nulos no significativos que fueron eliminados.
# Otro dataframe de marketing, donde se visualizaron 3 campañas para cada producto, y aparecía un costo que no se especificaba si era total de la campaña o había que mutiplicarlo por la cantidad vendida de ese producto.
# Luego de realizar el merge de ambos (por producto), se encontró que aparecían  ventas triplicadas por el hecho de haber 3 campañas de marketing (RSS, TV, Email) por cada producto. Hubo ventas realizadas dentro y fuera de los períodos de marketing, por ello, se optó por generar dos dataframes diferentes, uno con las ventas dentro del período de marketing, y otro con las ventas fuera del período.
# KPIs planteados:
#  - Importe total de ventas concretado por mes
#  - Cantidad de productos totales vendidos por mes
#  - Volumen de venta por categorías
#  - Impacto de las campañas de marketing en las ventas
#
# **Análisis de los histogramas** :
# Mediante los histogramas de precios y de cantidades se observó una distribución uniforme, es decir, no hubo un valor de compra o precio dominante.
# Las ventas totales, aparecen sesgadas a la derecha, lo que indica que pocas transacciones de alto valor (outliers) generaron la mayor parte de los ingresos totales.
# La gran mayoría (moda) de las ventas fueron de valor bajo a moderado (aproximadamente entre 200 y 300).
# El histograma de costo de marketing mostró una curva normal y simétrica, lo que indica que la inversión por campaña fue muy similar y con un valor promedio entre 4.5 y 5.
# La distribución de precios mostró ser bastante uniforme a lo largo de todo el rango (aproximadamente de 25 a 125).
# En el histograma de cantidades, se vió que la distribución fue uniforme y casi plana en todo el rango (de 1 a 12), lo que significa que no hubo una clara preferencia de compra por una cantidad específica.
#
# **Análisis de los Boxplots :**
# 1. Boxplot de Precios
# Mediana: Aproximadamente 75-80. Esto indica que el 50% de las transacciones (o productos) tuvieron un precio igual o inferior a este valor.
# Rango Intercuartil: Va desde aproximadamente 50 hasta 100. Esto indica que el 50% de los precios se concentró en ese rango.
# Distribución: Es relativamente simétrica dentro de la caja (la mediana está cerca del centro de la misma).
# Bigotes: Los bigotes se extienden desde aproximadamente 20 hasta 125.
# Correlación con el Histograma de Precios: El boxplot confirma la uniformidad, aunque la mediana está definida alrededor de 75-80.
#
# 2. Boxplot de Valor de Venta (Ventas Totales)
# Mediana: Aproximadamente 420. La mitad de las ventas totales estuvo por debajo de este valor.
# Rango Intercuartil: Va desde aproximadamente 220 hasta 700.
# Distribución: Es asimétrica, la línea de la mediana (420) está más cerca de la parte inferior de la caja (220).
# Insight: Esto confirma la asimetría positiva vista en el histograma. El 75% de las ventas fueron inferiores a 700.
# Outliers: Hay varios puntos por encima del bigote superior, especialmente alrededor de 1400 y 1500.
# Insight: Confirma la existencia de ventas totales muy altas que son raras, pero que tiran el promedio hacia arriba.
#
# 3. Boxplot de Cantidad
# Mediana: Aproximadamente 7.
# Rango Intercuartil: Se extiende desde aproximadamente 3 hasta 9.
# Distribución: Es relativamente simétrica (la mediana está cerca del centro de la caja).
# Rango Total: El rango completo se extiende de 1 a 12, confirmando que todas las cantidades de venta se limitan a este intervalo.
# Correlación con el Histograma de Cantidades: El boxplot refuerza que, aunque la distribución era uniforme, la mitad de las transacciones son de 3 a 9 unidades, con el valor central en 7.
#
# **Análisis de la Matríz de Correlación:**
# - Precio vs. Cantidad : -0.002388 casi nula, no hay relación lineal. Es un comportamiento raro, pero la cantidad que compraron los clientes fue independiente del precio de los productos.
# - Precio vs. Valor de Venta : 0.558846 positiva moderada/fuerte. El precio tuvo un efecto significativo, aunque no dominante, en el valor total de la transacción.
# - Cantidad vs. Valor de Venta : 0.773009 positiva fuerte y dominante. La cantidad de unidades compradas fue el factor que más contribuyó a determinar el valor total de las ventas.
#
# **Análisis del alcance de las campañas de markerting : **
# En el gráfico de ventas mensuales, a primera vista la campaña pareciera haber sido efectiva, hubo un crecimiento y un pico en el mes 5, que pareciera ser producto del comienzo de la misma, aunque luego hubo un descenso abrupto en el mes 6, y finalmente creció un poco y se estabilizó sobre los últimos meses del año.
# En el gráfico de ventas totales por producto dentro y fuera de campaña, también se puede observar que se vendieron muchos más productos dentro de campañas que fuera de campañas, lo que refuerza el pensar que las campañas fueron beneficiosas para el negocio.
#
# **Análisis de categorías de productos**
# La categoría con total de ventas más alto fue la de Electrodomésticos. En cuanto a las categorías secundarias (Decoración y Electrónica), generaron un volumen de ventas similar, ligeramente inferior a los Electrodomésticos.
#
# **Productos más vendidos**
# En los gráficos de ventas totales por productos dentro y fuera de campaña, y en el de ventas por producto, se observa que la batidora es el producto que más se vendió fuera de campaña, y que dentro de campaña lo fueron la lámpara de mesa, los auriculares y los microondas.
#
# **Conclusiones**
# El análisis del proyecto reveló que la **cantidad de unidades vendidas** es el factor más determinante del ingreso (coeficiente de correlación 0.773), y que esta métrica es independiente del precio del producto. A nivel de la estrategia de marketing, se identificó que la inversión pareció ser beneficiosa, con el pico máximo de ventas del mes 5, y que generó aumentos significativos en las ventas de algunos productos específicos, la mayoría pertenecientes a la categoría líder de ingresos, es decir, Electrodomésticos.
